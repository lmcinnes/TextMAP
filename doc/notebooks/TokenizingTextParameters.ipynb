# %% [markdown]
# # TextMAP Tokenization

# %% [markdown]
# Here we are going to walk through the various transforms available within textmap used in word and document embeddings.  In general the process of tokenization is given a string of text (a document), return a sequence of tokens (words or word-like objects).  While one would like to assume this is a simple processes of breaking a string on spaces, in general language is much more complex than that - some tokens have non-alpha numeric characters, periods, spaces, etc. or the language may not use the roman alphabet at all.  In english, tokens such as  "can't", "x-ray", "Ms.", "$5.00", "www\.words\.com", "john\@doe\.edu", "3D", "Las Vegas", ":-D", "20\%", etc., have several 'natural' ways to tokenize them depending on the use case.
#
# TextMAP contains several standard NLP tokenizers all mad eto work within a standard sci-kit learn fit_transformer API.  There are several default options available, each of which makes slightly different choices to tokenize a document, though they all have the flexibility for a user to provide their own tokenizer instances.  TextMAP also contains a tansformer for bigram and ngram contraction to replace common occuring pairs (or n-tuples more generally) with a single token for the pair (or n-gram), to deal with multi-token terms like "Las Vegas", "ice cream", "without loss of generality", etc. in an unsupervised or semi-supervised fashion.
#
# To demonstrate some of the tokenizers and their usage we'll walk through some examples and explore the options available.

# %% [markdown]
# First let's get some data! We'll use 20newgroups and remove documents less than 100 characters long.

# %%
import sklearn.datasets
import numpy as np
import pandas
import vectorizers
import textmap
import textmap.tokenizers 
import textmap.transformers
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /Users/colin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
news = sklearn.datasets.fetch_20newsgroups(remove=('headers', 'footers', 'quotes'))

# %%
long_enough = [len(t) > 100 for t in news['data']]
data = np.array(news['data'])
data = data[long_enough]
targets = np.array(news.target)
targets = targets[long_enough]
target_names = np.array(news.target_names)

# %% [markdown]
# ### Default Tokenizers:

# %% [markdown]
# Let's look at a couple documents and notice all of the awful text in there... numbers, email addresses, hyphens, signatures, special characters, etc... and these are some of the better ones!

# %%
data[0:3]
# Out:
# array(['I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.',
#        "A fair number of brave souls who upgraded their SI clock oscillator have\nshared their experiences for this poll. Please send a brief message detailing\nyour experiences with the procedure. Top speed attained, CPU rated speed,\nadd on cards and adapters, heat sinks, hour of usage per day, floppy disk\nfunctionality with 800 and 1.4 m floppies are especially requested.\n\nI will be summarizing in the next two days, so please add to the network\nknowledge base if you have done the clock upgrade and haven't answered this\npoll. Thanks.",
#        'well folks, my mac plus finally gave up the ghost this weekend after\nstarting life as a 512k way back in 1985.  sooo, i\'m in the market for a\nnew machine a bit sooner than i intended to be...\n\ni\'m looking into picking up a powerbook 160 or maybe 180 and have a bunch\nof questions that (hopefully) somebody can answer:\n\n* does anybody know any dirt on when the next round of powerbook\nintroductions are expected?  i\'d heard the 185c was supposed to make an\nappearence "this summer" but haven\'t heard anymore on it - and since i\ndon\'t have access to macleak, i was wondering if anybody out there had\nmore info...\n\n* has anybody heard rumors about price drops to the powerbook line like the\nones the duo\'s just went through recently?\n\n* what\'s the impression of the display on the 180?  i could probably swing\na 180 if i got the 80Mb disk rather than the 120, but i don\'t really have\na feel for how much "better" the display is (yea, it looks great in the\nstore, but is that all "wow" or is it really that good?).  could i solicit\nsome opinions of people who use the 160 and 180 day-to-day on if its worth\ntaking the disk size and money hit to get the active display?  (i realize\nthis is a real subjective question, but i\'ve only played around with the\nmachines in a computer store breifly and figured the opinions of somebody\nwho actually uses the machine daily might prove helpful).\n\n* how well does hellcats perform?  ;)\n\nthanks a bunch in advance for any info - if you could email, i\'ll post a\nsummary (news reading time is at a premium with finals just around the\ncorner... :( )\n--\nTom Willis  \\  twillis@ecn.purdue.edu    \\    Purdue Electrical Engineering'],
#       dtype='<U74878')

# %% [markdown]
# The SKlearnTokenizer tokenizes the corpus using the same methodology as CountVectorizer.

# %%
# %%time
tokens = textmap.tokenizers.SKLearnTokenizer().fit_transform(data)
# Out:
# CPU times: user 4.37 s, sys: 2.03 s, total: 6.4 s
# Wall time: 9.35 s

# %% [markdown]
# Looking at the first 3 documents we can see how it performs. Notice that is removes tokes of length 1 only produces 'word-like' tokens

# %%
tokens[0:3]
# Out:
# (('was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'saw',
#   'the',
#   'other',
#   'day',
#   'it',
#   'was',
#   'door',
#   'sports',
#   'car',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s',
#   'early',
#   '70s',
#   'it',
#   'was',
#   'called',
#   'bricklin',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small',
#   'in',
#   'addition',
#   'the',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body',
#   'this',
#   'is',
#   'all',
#   'know',
#   'if',
#   'anyone',
#   'can',
#   'tellme',
#   'model',
#   'name',
#   'engine',
#   'specs',
#   'years',
#   'of',
#   'production',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   'history',
#   'or',
#   'whatever',
#   'info',
#   'you',
#   'have',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car',
#   'please',
#   'mail'),
#  ('fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have',
#   'shared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll',
#   'please',
#   'send',
#   'brief',
#   'message',
#   'detailing',
#   'your',
#   'experiences',
#   'with',
#   'the',
#   'procedure',
#   'top',
#   'speed',
#   'attained',
#   'cpu',
#   'rated',
#   'speed',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   'heat',
#   'sinks',
#   'hour',
#   'of',
#   'usage',
#   'per',
#   'day',
#   'floppy',
#   'disk',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two',
#   'days',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network',
#   'knowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   'haven',
#   'answered',
#   'this',
#   'poll',
#   'thanks'),
#  ('well',
#   'folks',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   'starting',
#   'life',
#   'as',
#   '512k',
#   'way',
#   'back',
#   'in',
#   '1985',
#   'sooo',
#   'in',
#   'the',
#   'market',
#   'for',
#   'new',
#   'machine',
#   'bit',
#   'sooner',
#   'than',
#   'intended',
#   'to',
#   'be',
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'bunch',
#   'of',
#   'questions',
#   'that',
#   'hopefully',
#   'somebody',
#   'can',
#   'answer',
#   'does',
#   'anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   'introductions',
#   'are',
#   'expected',
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an',
#   'appearence',
#   'this',
#   'summer',
#   'but',
#   'haven',
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   'and',
#   'since',
#   'don',
#   'have',
#   'access',
#   'to',
#   'macleak',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had',
#   'more',
#   'info',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the',
#   'ones',
#   'the',
#   'duo',
#   'just',
#   'went',
#   'through',
#   'recently',
#   'what',
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180',
#   'could',
#   'probably',
#   'swing',
#   '180',
#   'if',
#   'got',
#   'the',
#   '80mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120',
#   'but',
#   'don',
#   'really',
#   'have',
#   'feel',
#   'for',
#   'how',
#   'much',
#   'better',
#   'the',
#   'display',
#   'is',
#   'yea',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the',
#   'store',
#   'but',
#   'is',
#   'that',
#   'all',
#   'wow',
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good',
#   'could',
#   'solicit',
#   'some',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day',
#   'to',
#   'day',
#   'on',
#   'if',
#   'its',
#   'worth',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display',
#   'realize',
#   'this',
#   'is',
#   'real',
#   'subjective',
#   'question',
#   'but',
#   've',
#   'only',
#   'played',
#   'around',
#   'with',
#   'the',
#   'machines',
#   'in',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   'who',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   'thanks',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   'if',
#   'you',
#   'could',
#   'email',
#   'll',
#   'post',
#   'summary',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the',
#   'corner',
#   'tom',
#   'willis',
#   'twillis',
#   'ecn',
#   'purdue',
#   'edu',
#   'purdue',
#   'electrical',
#   'engineering'))

# %% [markdown]
# NLTK's default tokenizer keeps the punctuation and tries to handle special characters more naturally.

# %%
# %%time
tokens = textmap.tokenizers.NLTKTokenizer().fit_transform(data)
# Out:
# CPU times: user 26.4 s, sys: 1.96 s, total: 28.3 s
# Wall time: 30 s

# %%
tokens[0:3]
# Out:
# (('i',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'i',
#   'saw',
#   'the',
#   'other',
#   'day',
#   '.',
#   'it',
#   'was',
#   'a',
#   '2-door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s/',
#   'early',
#   '70s',
#   '.',
#   'it',
#   'was',
#   'called',
#   'a',
#   'bricklin',
#   '.',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small',
#   '.',
#   'in',
#   'addition',
#   ',',
#   'the',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body',
#   '.',
#   'this',
#   'is',
#   'all',
#   'i',
#   'know',
#   '.',
#   'if',
#   'anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name',
#   ',',
#   'engine',
#   'specs',
#   ',',
#   'years',
#   'of',
#   'production',
#   ',',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   ',',
#   'history',
#   ',',
#   'or',
#   'whatever',
#   'info',
#   'you',
#   'have',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car',
#   ',',
#   'please',
#   'e-mail',
#   '.'),
#  ('a',
#   'fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have',
#   'shared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll',
#   '.',
#   'please',
#   'send',
#   'a',
#   'brief',
#   'message',
#   'detailing',
#   'your',
#   'experiences',
#   'with',
#   'the',
#   'procedure',
#   '.',
#   'top',
#   'speed',
#   'attained',
#   ',',
#   'cpu',
#   'rated',
#   'speed',
#   ',',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   ',',
#   'heat',
#   'sinks',
#   ',',
#   'hour',
#   'of',
#   'usage',
#   'per',
#   'day',
#   ',',
#   'floppy',
#   'disk',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   '.',
#   'i',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two',
#   'days',
#   ',',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network',
#   'knowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   'have',
#   "n't",
#   'answered',
#   'this',
#   'poll',
#   '.',
#   'thanks',
#   '.'),
#  ('well',
#   'folks',
#   ',',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   'starting',
#   'life',
#   'as',
#   'a',
#   '512k',
#   'way',
#   'back',
#   'in',
#   '1985.',
#   'sooo',
#   ',',
#   'i',
#   "'m",
#   'in',
#   'the',
#   'market',
#   'for',
#   'a',
#   'new',
#   'machine',
#   'a',
#   'bit',
#   'sooner',
#   'than',
#   'i',
#   'intended',
#   'to',
#   'be',
#   '...',
#   'i',
#   "'m",
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'a',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'a',
#   'bunch',
#   'of',
#   'questions',
#   'that',
#   '(',
#   'hopefully',
#   ')',
#   'somebody',
#   'can',
#   'answer',
#   ':',
#   '*',
#   'does',
#   'anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   'introductions',
#   'are',
#   'expected',
#   '?',
#   'i',
#   "'d",
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an',
#   'appearence',
#   '``',
#   'this',
#   'summer',
#   "''",
#   'but',
#   'have',
#   "n't",
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   '-',
#   'and',
#   'since',
#   'i',
#   'do',
#   "n't",
#   'have',
#   'access',
#   'to',
#   'macleak',
#   ',',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had',
#   'more',
#   'info',
#   '...',
#   '*',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the',
#   'ones',
#   'the',
#   'duo',
#   "'s",
#   'just',
#   'went',
#   'through',
#   'recently',
#   '?',
#   '*',
#   'what',
#   "'s",
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180',
#   '?',
#   'i',
#   'could',
#   'probably',
#   'swing',
#   'a',
#   '180',
#   'if',
#   'i',
#   'got',
#   'the',
#   '80mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120',
#   ',',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'really',
#   'have',
#   'a',
#   'feel',
#   'for',
#   'how',
#   'much',
#   '``',
#   'better',
#   "''",
#   'the',
#   'display',
#   'is',
#   '(',
#   'yea',
#   ',',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the',
#   'store',
#   ',',
#   'but',
#   'is',
#   'that',
#   'all',
#   '``',
#   'wow',
#   "''",
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good',
#   '?',
#   ')',
#   '.',
#   'could',
#   'i',
#   'solicit',
#   'some',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day-to-day',
#   'on',
#   'if',
#   'its',
#   'worth',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display',
#   '?',
#   '(',
#   'i',
#   'realize',
#   'this',
#   'is',
#   'a',
#   'real',
#   'subjective',
#   'question',
#   ',',
#   'but',
#   'i',
#   "'ve",
#   'only',
#   'played',
#   'around',
#   'with',
#   'the',
#   'machines',
#   'in',
#   'a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   'who',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   ')',
#   '.',
#   '*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   '?',
#   ';',
#   ')',
#   'thanks',
#   'a',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   '-',
#   'if',
#   'you',
#   'could',
#   'email',
#   ',',
#   'i',
#   "'ll",
#   'post',
#   'a',
#   'summary',
#   '(',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the',
#   'corner',
#   '...',
#   ':',
#   '(',
#   ')',
#   '--',
#   'tom',
#   'willis',
#   '\\',
#   'twillis',
#   '@',
#   'ecn.purdue.edu',
#   '\\',
#   'purdue',
#   'electrical',
#   'engineering'))

# %% [markdown]
# NLTK's tweet tokenizer tries to tokenize emojis, urls, and email addresses as single tokens as well.

# %%
# %%time
tokens = textmap.tokenizers.NLTKTweetTokenizer().fit_transform(data)
# Out:
# CPU times: user 9.85 s, sys: 238 ms, total: 10.1 s
# Wall time: 10.1 s

# %%
tokens[0:3]
# Out:
# (('i',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'i',
#   'saw',
#   'the',
#   'other',
#   'day',
#   '.',
#   'it',
#   'was',
#   'a',
#   '2',
#   '-',
#   'door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s',
#   '/',
#   'early',
#   '70s',
#   '.',
#   'it',
#   'was',
#   'called',
#   'a',
#   'bricklin',
#   '.',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small',
#   '.',
#   'in',
#   'addition',
#   ',',
#   'the',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body',
#   '.',
#   'this',
#   'is',
#   'all',
#   'i',
#   'know',
#   '.',
#   'if',
#   'anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name',
#   ',',
#   'engine',
#   'specs',
#   ',',
#   'years',
#   'of',
#   'production',
#   ',',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   ',',
#   'history',
#   ',',
#   'or',
#   'whatever',
#   'info',
#   'you',
#   'have',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car',
#   ',',
#   'please',
#   'e-mail',
#   '.'),
#  ('a',
#   'fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have',
#   'shared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll',
#   '.',
#   'please',
#   'send',
#   'a',
#   'brief',
#   'message',
#   'detailing',
#   'your',
#   'experiences',
#   'with',
#   'the',
#   'procedure',
#   '.',
#   'top',
#   'speed',
#   'attained',
#   ',',
#   'cpu',
#   'rated',
#   'speed',
#   ',',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   ',',
#   'heat',
#   'sinks',
#   ',',
#   'hour',
#   'of',
#   'usage',
#   'per',
#   'day',
#   ',',
#   'floppy',
#   'disk',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   '.',
#   'i',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two',
#   'days',
#   ',',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network',
#   'knowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   "haven't",
#   'answered',
#   'this',
#   'poll',
#   '.',
#   'thanks',
#   '.'),
#  ('well',
#   'folks',
#   ',',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   'starting',
#   'life',
#   'as',
#   'a',
#   '512k',
#   'way',
#   'back',
#   'in',
#   '1985',
#   '.',
#   'sooo',
#   ',',
#   "i'm",
#   'in',
#   'the',
#   'market',
#   'for',
#   'a',
#   'new',
#   'machine',
#   'a',
#   'bit',
#   'sooner',
#   'than',
#   'i',
#   'intended',
#   'to',
#   'be',
#   '...',
#   "i'm",
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'a',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'a',
#   'bunch',
#   'of',
#   'questions',
#   'that',
#   '(',
#   'hopefully',
#   ')',
#   'somebody',
#   'can',
#   'answer',
#   ':',
#   '*',
#   'does',
#   'anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   'introductions',
#   'are',
#   'expected',
#   '?',
#   "i'd",
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an',
#   'appearence',
#   '"',
#   'this',
#   'summer',
#   '"',
#   'but',
#   "haven't",
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   '-',
#   'and',
#   'since',
#   'i',
#   "don't",
#   'have',
#   'access',
#   'to',
#   'macleak',
#   ',',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had',
#   'more',
#   'info',
#   '...',
#   '*',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the',
#   'ones',
#   'the',
#   "duo's",
#   'just',
#   'went',
#   'through',
#   'recently',
#   '?',
#   '*',
#   "what's",
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180',
#   '?',
#   'i',
#   'could',
#   'probably',
#   'swing',
#   'a',
#   '180',
#   'if',
#   'i',
#   'got',
#   'the',
#   '80mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120',
#   ',',
#   'but',
#   'i',
#   "don't",
#   'really',
#   'have',
#   'a',
#   'feel',
#   'for',
#   'how',
#   'much',
#   '"',
#   'better',
#   '"',
#   'the',
#   'display',
#   'is',
#   '(',
#   'yea',
#   ',',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the',
#   'store',
#   ',',
#   'but',
#   'is',
#   'that',
#   'all',
#   '"',
#   'wow',
#   '"',
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good',
#   '?',
#   ')',
#   '.',
#   'could',
#   'i',
#   'solicit',
#   'some',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day-to-day',
#   'on',
#   'if',
#   'its',
#   'worth',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display',
#   '?',
#   '(',
#   'i',
#   'realize',
#   'this',
#   'is',
#   'a',
#   'real',
#   'subjective',
#   'question',
#   ',',
#   'but',
#   "i've",
#   'only',
#   'played',
#   'around',
#   'with',
#   'the',
#   'machines',
#   'in',
#   'a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   'who',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   ')',
#   '.',
#   '*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   '?',
#   ';)',
#   'thanks',
#   'a',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   '-',
#   'if',
#   'you',
#   'could',
#   'email',
#   ',',
#   "i'll",
#   'post',
#   'a',
#   'summary',
#   '(',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the',
#   'corner',
#   '...',
#   ':(',
#   ')',
#   '-',
#   '-',
#   'tom',
#   'willis',
#   '\\',
#   'twillis@ecn.purdue.edu',
#   '\\',
#   'purdue',
#   'electrical',
#   'engineering'))

# %% [markdown]
# SpaCy uses several language processing techniques to make even more refined choices.

# %%
# %%time
tokens = textmap.tokenizers.SpacyTokenizer().fit_transform(data)
# Out:
# CPU times: user 26.2 s, sys: 214 ms, total: 26.4 s
# Wall time: 26.5 s

# %%
tokens[0:3]
# Out:
# (('i',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'i',
#   'saw',
#   '\n',
#   'the',
#   'other',
#   'day',
#   '.',
#   'it',
#   'was',
#   'a',
#   '2-door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s/',
#   '\n',
#   'early',
#   '70s',
#   '.',
#   'it',
#   'was',
#   'called',
#   'a',
#   'bricklin',
#   '.',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small',
#   '.',
#   'in',
#   'addition',
#   ',',
#   '\n',
#   'the',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body',
#   '.',
#   'this',
#   'is',
#   '\n',
#   'all',
#   'i',
#   'know',
#   '.',
#   'if',
#   'anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name',
#   ',',
#   'engine',
#   'specs',
#   ',',
#   'years',
#   '\n',
#   'of',
#   'production',
#   ',',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   ',',
#   'history',
#   ',',
#   'or',
#   'whatever',
#   'info',
#   'you',
#   '\n',
#   'have',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car',
#   ',',
#   'please',
#   'e',
#   '-',
#   'mail',
#   '.'),
#  ('a',
#   'fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have',
#   '\n',
#   'shared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll',
#   '.',
#   'please',
#   'send',
#   'a',
#   'brief',
#   'message',
#   'detailing',
#   '\n',
#   'your',
#   'experiences',
#   'with',
#   'the',
#   'procedure',
#   '.',
#   'top',
#   'speed',
#   'attained',
#   ',',
#   'cpu',
#   'rated',
#   'speed',
#   ',',
#   '\n',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   ',',
#   'heat',
#   'sinks',
#   ',',
#   'hour',
#   'of',
#   'usage',
#   'per',
#   'day',
#   ',',
#   'floppy',
#   'disk',
#   '\n',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   '.',
#   '\n\n',
#   'i',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two',
#   'days',
#   ',',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network',
#   '\n',
#   'knowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   'have',
#   "n't",
#   'answered',
#   'this',
#   '\n',
#   'poll',
#   '.',
#   'thanks',
#   '.'),
#  ('well',
#   'folks',
#   ',',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   '\n',
#   'starting',
#   'life',
#   'as',
#   'a',
#   '512k',
#   'way',
#   'back',
#   'in',
#   '1985',
#   '.',
#   ' ',
#   'sooo',
#   ',',
#   'i',
#   "'m",
#   'in',
#   'the',
#   'market',
#   'for',
#   'a',
#   '\n',
#   'new',
#   'machine',
#   'a',
#   'bit',
#   'sooner',
#   'than',
#   'i',
#   'intended',
#   'to',
#   'be',
#   '...',
#   '\n\n',
#   'i',
#   "'m",
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'a',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'a',
#   'bunch',
#   '\n',
#   'of',
#   'questions',
#   'that',
#   '(',
#   'hopefully',
#   ')',
#   'somebody',
#   'can',
#   'answer',
#   ':',
#   '\n\n',
#   '*',
#   'does',
#   'anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   '\n',
#   'introductions',
#   'are',
#   'expected',
#   '?',
#   ' ',
#   'i',
#   "'d",
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an',
#   '\n',
#   'appearence',
#   '"',
#   'this',
#   'summer',
#   '"',
#   'but',
#   'have',
#   "n't",
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   '-',
#   'and',
#   'since',
#   'i',
#   '\n',
#   'do',
#   "n't",
#   'have',
#   'access',
#   'to',
#   'macleak',
#   ',',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had',
#   '\n',
#   'more',
#   'info',
#   '...',
#   '\n\n',
#   '*',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the',
#   '\n',
#   'ones',
#   'the',
#   'duo',
#   "'s",
#   'just',
#   'went',
#   'through',
#   'recently',
#   '?',
#   '\n\n',
#   '*',
#   'what',
#   "'s",
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180',
#   '?',
#   ' ',
#   'i',
#   'could',
#   'probably',
#   'swing',
#   '\n',
#   'a',
#   '180',
#   'if',
#   'i',
#   'got',
#   'the',
#   '80mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120',
#   ',',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'really',
#   'have',
#   '\n',
#   'a',
#   'feel',
#   'for',
#   'how',
#   'much',
#   '"',
#   'better',
#   '"',
#   'the',
#   'display',
#   'is',
#   '(',
#   'yea',
#   ',',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the',
#   '\n',
#   'store',
#   ',',
#   'but',
#   'is',
#   'that',
#   'all',
#   '"',
#   'wow',
#   '"',
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good',
#   '?',
#   ')',
#   '.',
#   ' ',
#   'could',
#   'i',
#   'solicit',
#   '\n',
#   'some',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day',
#   '-',
#   'to',
#   '-',
#   'day',
#   'on',
#   'if',
#   'its',
#   'worth',
#   '\n',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display',
#   '?',
#   ' ',
#   '(',
#   'i',
#   'realize',
#   '\n',
#   'this',
#   'is',
#   'a',
#   'real',
#   'subjective',
#   'question',
#   ',',
#   'but',
#   'i',
#   "'ve",
#   'only',
#   'played',
#   'around',
#   'with',
#   'the',
#   '\n',
#   'machines',
#   'in',
#   'a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   '\n',
#   'who',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   ')',
#   '.',
#   '\n\n',
#   '*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   '?',
#   ' ',
#   ';)',
#   '\n\n',
#   'thanks',
#   'a',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   '-',
#   'if',
#   'you',
#   'could',
#   'email',
#   ',',
#   'i',
#   "'ll",
#   'post',
#   'a',
#   '\n',
#   'summary',
#   '(',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the',
#   '\n',
#   'corner',
#   '...',
#   ':(',
#   ')',
#   '\n',
#   '--',
#   '\n',
#   'tom',
#   'willis',
#   ' ',
#   '\\',
#   ' ',
#   'twillis@ecn.purdue.edu',
#   '   ',
#   '\\',
#   '   ',
#   'purdue',
#   'electrical',
#   'engineering'))

# %% [markdown]
# Stanza uses other custom language processing tools (which we default to English) for tokenization.  Because of all of the additional NLP processing, Stanza can be time consuming for large corpora.

# %%
# %%time
tokens = textmap.tokenizers.StanzaTokenizer().fit_transform(data[0:100])
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.0.0.json: 116kB [00:00, 4.07MB/s]
# 2020-04-24 17:34:05 INFO: Downloading these customized packages for language: en (English)...
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ewt     |
# =======================
#
# 2020-04-24 17:34:05 INFO: File exists: /Users/colin/stanza_resources/en/tokenize/ewt.pt.
# 2020-04-24 17:34:05 INFO: Finished downloading models and saved to /Users/colin/stanza_resources.
# 2020-04-24 17:34:05 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ewt     |
# =======================
#
# 2020-04-24 17:34:05 INFO: Use device: cpu
# 2020-04-24 17:34:05 INFO: Loading: tokenize
# 2020-04-24 17:34:05 INFO: Done loading processors!
# CPU times: user 1min 46s, sys: 2.77 s, total: 1min 49s
# Wall time: 29.7 s

# %%
tokens[0:3]
# Out:
# (('i',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'i',
#   'saw',
#   'the',
#   'other',
#   'day',
#   '.',
#   'it',
#   'was',
#   'a',
#   '2',
#   '-',
#   'door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s',
#   '/',
#   'early',
#   '70s',
#   '.',
#   'it',
#   'was',
#   'called',
#   'a',
#   'bricklin',
#   '.',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small',
#   '.',
#   'in',
#   'addition',
#   ',',
#   'the',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body',
#   '.',
#   'this',
#   'is',
#   'all',
#   'i',
#   'know',
#   '.',
#   'if',
#   'anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name',
#   ',',
#   'engine',
#   'specs',
#   ',',
#   'years',
#   'of',
#   'production',
#   ',',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   ',',
#   'history',
#   ',',
#   'or',
#   'whatever',
#   'info',
#   'you',
#   'have',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car',
#   ',',
#   'please',
#   'e-mail',
#   '.'),
#  ('a',
#   'fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have',
#   'shared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll',
#   '.',
#   'please',
#   'send',
#   'a',
#   'brief',
#   'message',
#   'detailing',
#   'your',
#   'experiences',
#   'with',
#   'the',
#   'procedure',
#   '.',
#   'top',
#   'speed',
#   'attained',
#   ',',
#   'cpu',
#   'rated',
#   'speed',
#   ',',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   ',',
#   'heat',
#   'sinks',
#   ',',
#   'hour',
#   'of',
#   'usage',
#   'per',
#   'day',
#   ',',
#   'floppy',
#   'disk',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   '.',
#   'i',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two',
#   'days',
#   ',',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network',
#   'knowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   'have',
#   "n't",
#   'answered',
#   'this',
#   'poll',
#   '.',
#   'thanks',
#   '.'),
#  ('well',
#   'folks',
#   ',',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   'starting',
#   'life',
#   'as',
#   'a',
#   '512',
#   'k',
#   'way',
#   'back',
#   'in',
#   '1985',
#   '.',
#   'sooo',
#   ',',
#   'i',
#   "'m",
#   'in',
#   'the',
#   'market',
#   'for',
#   'a',
#   'new',
#   'machine',
#   'a',
#   'bit',
#   'sooner',
#   'than',
#   'i',
#   'intended',
#   'to',
#   'be',
#   '...',
#   'i',
#   "'m",
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'a',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'a',
#   'bunch',
#   'of',
#   'questions',
#   'that',
#   '(',
#   'hopefully',
#   ')',
#   'somebody',
#   'can',
#   'answer',
#   ':',
#   '*',
#   'does',
#   'anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   'introductions',
#   'are',
#   'expected',
#   '?',
#   'i',
#   "'d",
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an',
#   'appearence',
#   '"',
#   'this',
#   'summer',
#   '"',
#   'but',
#   'have',
#   "n't",
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   '-',
#   'and',
#   'since',
#   'i',
#   'do',
#   "n't",
#   'have',
#   'access',
#   'to',
#   'macleak',
#   ',',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had',
#   'more',
#   'info',
#   '...',
#   '*',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the',
#   'ones',
#   'the',
#   'duo',
#   "'s",
#   'just',
#   'went',
#   'through',
#   'recently',
#   '?',
#   '*',
#   'what',
#   "'s",
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180',
#   '?',
#   'i',
#   'could',
#   'probably',
#   'swing',
#   'a',
#   '180',
#   'if',
#   'i',
#   'got',
#   'the',
#   '80',
#   'mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120',
#   ',',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'really',
#   'have',
#   'a',
#   'feel',
#   'for',
#   'how',
#   'much',
#   '"',
#   'better',
#   '"',
#   'the',
#   'display',
#   'is',
#   '(',
#   'yea',
#   ',',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the',
#   'store',
#   ',',
#   'but',
#   'is',
#   'that',
#   'all',
#   '"',
#   'wow',
#   '"',
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good',
#   '?',
#   ')',
#   '.',
#   'could',
#   'i',
#   'solicit',
#   'some',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day',
#   '-',
#   'to',
#   '-',
#   'day',
#   'on',
#   'if',
#   'it',
#   's',
#   'worth',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display',
#   '?',
#   '(',
#   'i',
#   'realize',
#   'this',
#   'is',
#   'a',
#   'real',
#   'subjective',
#   'question',
#   ',',
#   'but',
#   'i',
#   "'ve",
#   'only',
#   'played',
#   'around',
#   'with',
#   'the',
#   'machines',
#   'in',
#   'a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   'who',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   ')',
#   '.',
#   '*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   '?',
#   ';)',
#   'thanks',
#   'a',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   '-',
#   'if',
#   'you',
#   'could',
#   'email',
#   ',',
#   'i',
#   "'ll",
#   'post',
#   'a',
#   'summary',
#   '(',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the',
#   'corner',
#   '...',
#   ':(',
#   ')',
#   '--',
#   'tom',
#   'willis',
#   '\\',
#   'twillis@ecn.purdue.edu',
#   '\\',
#   'purdue',
#   'electrical',
#   'engineering'))

# %% [markdown]
# ## Tokenizer options:

# %% [markdown]
# All of the tokenizers can return tokenization by document (default) but also by sentence (returning a sequence per sentence) or by sentence by document (a sequence of token sequences per sentence per document). This is more time consuming as finding sentence breaks presents its own challenges. For example

# %%
# %%time
tokens = textmap.tokenizers.NLTKTokenizer(tokenize_by = "sentence").fit_transform(data)
tokens[0:3]
# Out:
# CPU times: user 32.7 s, sys: 770 ms, total: 33.5 s
# Wall time: 34.3 s
# (('i',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'i',
#   'saw',
#   'the',
#   'other',
#   'day',
#   '.'),
#  ('it',
#   'was',
#   'a',
#   '2-door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s/',
#   'early',
#   '70s',
#   '.'),
#  ('it', 'was', 'called', 'a', 'bricklin', '.'))

# %%
# %%time
tokens = textmap.tokenizers.NLTKTweetTokenizer(tokenize_by = "sentence_by_document").fit_transform(data)
tokens[0:3]
# Out:
# CPU times: user 15.1 s, sys: 575 ms, total: 15.7 s
# Wall time: 15.7 s
# ((('i',
#    'was',
#    'wondering',
#    'if',
#    'anyone',
#    'out',
#    'there',
#    'could',
#    'enlighten',
#    'me',
#    'on',
#    'this',
#    'car',
#    'i',
#    'saw',
#    'the',
#    'other',
#    'day',
#    '.'),
#   ('it',
#    'was',
#    'a',
#    '2',
#    '-',
#    'door',
#    'sports',
#    'car',
#    ',',
#    'looked',
#    'to',
#    'be',
#    'from',
#    'the',
#    'late',
#    '60s',
#    '/',
#    'early',
#    '70s',
#    '.'),
#   ('it', 'was', 'called', 'a', 'bricklin', '.'),
#   ('the', 'doors', 'were', 'really', 'small', '.'),
#   ('in',
#    'addition',
#    ',',
#    'the',
#    'front',
#    'bumper',
#    'was',
#    'separate',
#    'from',
#    'the',
#    'rest',
#    'of',
#    'the',
#    'body',
#    '.'),
#   ('this', 'is', 'all', 'i', 'know', '.'),
#   ('if',
#    'anyone',
#    'can',
#    'tellme',
#    'a',
#    'model',
#    'name',
#    ',',
#    'engine',
#    'specs',
#    ',',
#    'years',
#    'of',
#    'production',
#    ',',
#    'where',
#    'this',
#    'car',
#    'is',
#    'made',
#    ',',
#    'history',
#    ',',
#    'or',
#    'whatever',
#    'info',
#    'you',
#    'have',
#    'on',
#    'this',
#    'funky',
#    'looking',
#    'car',
#    ',',
#    'please',
#    'e-mail',
#    '.')),
#  (('a',
#    'fair',
#    'number',
#    'of',
#    'brave',
#    'souls',
#    'who',
#    'upgraded',
#    'their',
#    'si',
#    'clock',
#    'oscillator',
#    'have',
#    'shared',
#    'their',
#    'experiences',
#    'for',
#    'this',
#    'poll',
#    '.'),
#   ('please',
#    'send',
#    'a',
#    'brief',
#    'message',
#    'detailing',
#    'your',
#    'experiences',
#    'with',
#    'the',
#    'procedure',
#    '.'),
#   ('top',
#    'speed',
#    'attained',
#    ',',
#    'cpu',
#    'rated',
#    'speed',
#    ',',
#    'add',
#    'on',
#    'cards',
#    'and',
#    'adapters',
#    ',',
#    'heat',
#    'sinks',
#    ',',
#    'hour',
#    'of',
#    'usage',
#    'per',
#    'day',
#    ',',
#    'floppy',
#    'disk',
#    'functionality',
#    'with',
#    '800',
#    'and',
#    '1.4',
#    'm',
#    'floppies',
#    'are',
#    'especially',
#    'requested',
#    '.'),
#   ('i',
#    'will',
#    'be',
#    'summarizing',
#    'in',
#    'the',
#    'next',
#    'two',
#    'days',
#    ',',
#    'so',
#    'please',
#    'add',
#    'to',
#    'the',
#    'network',
#    'knowledge',
#    'base',
#    'if',
#    'you',
#    'have',
#    'done',
#    'the',
#    'clock',
#    'upgrade',
#    'and',
#    "haven't",
#    'answered',
#    'this',
#    'poll',
#    '.'),
#   ('thanks', '.')),
#  (('well',
#    'folks',
#    ',',
#    'my',
#    'mac',
#    'plus',
#    'finally',
#    'gave',
#    'up',
#    'the',
#    'ghost',
#    'this',
#    'weekend',
#    'after',
#    'starting',
#    'life',
#    'as',
#    'a',
#    '512k',
#    'way',
#    'back',
#    'in',
#    '1985',
#    '.',
#    'sooo',
#    ',',
#    "i'm",
#    'in',
#    'the',
#    'market',
#    'for',
#    'a',
#    'new',
#    'machine',
#    'a',
#    'bit',
#    'sooner',
#    'than',
#    'i',
#    'intended',
#    'to',
#    'be',
#    '...',
#    "i'm",
#    'looking',
#    'into',
#    'picking',
#    'up',
#    'a',
#    'powerbook',
#    '160',
#    'or',
#    'maybe',
#    '180',
#    'and',
#    'have',
#    'a',
#    'bunch',
#    'of',
#    'questions',
#    'that',
#    '(',
#    'hopefully',
#    ')',
#    'somebody',
#    'can',
#    'answer',
#    ':',
#    '*',
#    'does',
#    'anybody',
#    'know',
#    'any',
#    'dirt',
#    'on',
#    'when',
#    'the',
#    'next',
#    'round',
#    'of',
#    'powerbook',
#    'introductions',
#    'are',
#    'expected',
#    '?'),
#   ("i'd",
#    'heard',
#    'the',
#    '185c',
#    'was',
#    'supposed',
#    'to',
#    'make',
#    'an',
#    'appearence',
#    '"',
#    'this',
#    'summer',
#    '"',
#    'but',
#    "haven't",
#    'heard',
#    'anymore',
#    'on',
#    'it',
#    '-',
#    'and',
#    'since',
#    'i',
#    "don't",
#    'have',
#    'access',
#    'to',
#    'macleak',
#    ',',
#    'i',
#    'was',
#    'wondering',
#    'if',
#    'anybody',
#    'out',
#    'there',
#    'had',
#    'more',
#    'info',
#    '...',
#    '*',
#    'has',
#    'anybody',
#    'heard',
#    'rumors',
#    'about',
#    'price',
#    'drops',
#    'to',
#    'the',
#    'powerbook',
#    'line',
#    'like',
#    'the',
#    'ones',
#    'the',
#    "duo's",
#    'just',
#    'went',
#    'through',
#    'recently',
#    '?'),
#   ('*',
#    "what's",
#    'the',
#    'impression',
#    'of',
#    'the',
#    'display',
#    'on',
#    'the',
#    '180',
#    '?'),
#   ('i',
#    'could',
#    'probably',
#    'swing',
#    'a',
#    '180',
#    'if',
#    'i',
#    'got',
#    'the',
#    '80mb',
#    'disk',
#    'rather',
#    'than',
#    'the',
#    '120',
#    ',',
#    'but',
#    'i',
#    "don't",
#    'really',
#    'have',
#    'a',
#    'feel',
#    'for',
#    'how',
#    'much',
#    '"',
#    'better',
#    '"',
#    'the',
#    'display',
#    'is',
#    '(',
#    'yea',
#    ',',
#    'it',
#    'looks',
#    'great',
#    'in',
#    'the',
#    'store',
#    ',',
#    'but',
#    'is',
#    'that',
#    'all',
#    '"',
#    'wow',
#    '"',
#    'or',
#    'is',
#    'it',
#    'really',
#    'that',
#    'good',
#    '?',
#    ')',
#    '.'),
#   ('could',
#    'i',
#    'solicit',
#    'some',
#    'opinions',
#    'of',
#    'people',
#    'who',
#    'use',
#    'the',
#    '160',
#    'and',
#    '180',
#    'day-to-day',
#    'on',
#    'if',
#    'its',
#    'worth',
#    'taking',
#    'the',
#    'disk',
#    'size',
#    'and',
#    'money',
#    'hit',
#    'to',
#    'get',
#    'the',
#    'active',
#    'display',
#    '?'),
#   ('(',
#    'i',
#    'realize',
#    'this',
#    'is',
#    'a',
#    'real',
#    'subjective',
#    'question',
#    ',',
#    'but',
#    "i've",
#    'only',
#    'played',
#    'around',
#    'with',
#    'the',
#    'machines',
#    'in',
#    'a',
#    'computer',
#    'store',
#    'breifly',
#    'and',
#    'figured',
#    'the',
#    'opinions',
#    'of',
#    'somebody',
#    'who',
#    'actually',
#    'uses',
#    'the',
#    'machine',
#    'daily',
#    'might',
#    'prove',
#    'helpful',
#    ')',
#    '.'),
#   ('*', 'how', 'well', 'does', 'hellcats', 'perform', '?'),
#   (';)',
#    'thanks',
#    'a',
#    'bunch',
#    'in',
#    'advance',
#    'for',
#    'any',
#    'info',
#    '-',
#    'if',
#    'you',
#    'could',
#    'email',
#    ',',
#    "i'll",
#    'post',
#    'a',
#    'summary',
#    '(',
#    'news',
#    'reading',
#    'time',
#    'is',
#    'at',
#    'a',
#    'premium',
#    'with',
#    'finals',
#    'just',
#    'around',
#    'the',
#    'corner',
#    '...',
#    ':(',
#    ')',
#    '-',
#    '-',
#    'tom',
#    'willis',
#    '\\',
#    'twillis@ecn.purdue.edu',
#    '\\',
#    'purdue',
#    'electrical',
#    'engineering')))

# %% [markdown]
# All tokenizers lower case by default but this option can be changed as well.  For example;

# %%
tokens = textmap.tokenizers.NLTKTokenizer(lower_case = False).fit_transform(data)
tokens[0:3]
# Out:
# (('I',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'I',
#   'saw',
#   'the',
#   'other',
#   'day',
#   '.',
#   'It',
#   'was',
#   'a',
#   '2-door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s/',
#   'early',
#   '70s',
#   '.',
#   'It',
#   'was',
#   'called',
#   'a',
#   'Bricklin',
#   '.',
#   'The',
#   'doors',
#   'were',
#   'really',
#   'small',
#   '.',
#   'In',
#   'addition',
#   ',',
#   'the',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body',
#   '.',
#   'This',
#   'is',
#   'all',
#   'I',
#   'know',
#   '.',
#   'If',
#   'anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name',
#   ',',
#   'engine',
#   'specs',
#   ',',
#   'years',
#   'of',
#   'production',
#   ',',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   ',',
#   'history',
#   ',',
#   'or',
#   'whatever',
#   'info',
#   'you',
#   'have',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car',
#   ',',
#   'please',
#   'e-mail',
#   '.'),
#  ('A',
#   'fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'SI',
#   'clock',
#   'oscillator',
#   'have',
#   'shared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll',
#   '.',
#   'Please',
#   'send',
#   'a',
#   'brief',
#   'message',
#   'detailing',
#   'your',
#   'experiences',
#   'with',
#   'the',
#   'procedure',
#   '.',
#   'Top',
#   'speed',
#   'attained',
#   ',',
#   'CPU',
#   'rated',
#   'speed',
#   ',',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   ',',
#   'heat',
#   'sinks',
#   ',',
#   'hour',
#   'of',
#   'usage',
#   'per',
#   'day',
#   ',',
#   'floppy',
#   'disk',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   '.',
#   'I',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two',
#   'days',
#   ',',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network',
#   'knowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   'have',
#   "n't",
#   'answered',
#   'this',
#   'poll',
#   '.',
#   'Thanks',
#   '.'),
#  ('well',
#   'folks',
#   ',',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   'starting',
#   'life',
#   'as',
#   'a',
#   '512k',
#   'way',
#   'back',
#   'in',
#   '1985.',
#   'sooo',
#   ',',
#   'i',
#   "'m",
#   'in',
#   'the',
#   'market',
#   'for',
#   'a',
#   'new',
#   'machine',
#   'a',
#   'bit',
#   'sooner',
#   'than',
#   'i',
#   'intended',
#   'to',
#   'be',
#   '...',
#   'i',
#   "'m",
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'a',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'a',
#   'bunch',
#   'of',
#   'questions',
#   'that',
#   '(',
#   'hopefully',
#   ')',
#   'somebody',
#   'can',
#   'answer',
#   ':',
#   '*',
#   'does',
#   'anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   'introductions',
#   'are',
#   'expected',
#   '?',
#   'i',
#   "'d",
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an',
#   'appearence',
#   '``',
#   'this',
#   'summer',
#   "''",
#   'but',
#   'have',
#   "n't",
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   '-',
#   'and',
#   'since',
#   'i',
#   'do',
#   "n't",
#   'have',
#   'access',
#   'to',
#   'macleak',
#   ',',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had',
#   'more',
#   'info',
#   '...',
#   '*',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the',
#   'ones',
#   'the',
#   'duo',
#   "'s",
#   'just',
#   'went',
#   'through',
#   'recently',
#   '?',
#   '*',
#   'what',
#   "'s",
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180',
#   '?',
#   'i',
#   'could',
#   'probably',
#   'swing',
#   'a',
#   '180',
#   'if',
#   'i',
#   'got',
#   'the',
#   '80Mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120',
#   ',',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'really',
#   'have',
#   'a',
#   'feel',
#   'for',
#   'how',
#   'much',
#   '``',
#   'better',
#   "''",
#   'the',
#   'display',
#   'is',
#   '(',
#   'yea',
#   ',',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the',
#   'store',
#   ',',
#   'but',
#   'is',
#   'that',
#   'all',
#   '``',
#   'wow',
#   "''",
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good',
#   '?',
#   ')',
#   '.',
#   'could',
#   'i',
#   'solicit',
#   'some',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day-to-day',
#   'on',
#   'if',
#   'its',
#   'worth',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display',
#   '?',
#   '(',
#   'i',
#   'realize',
#   'this',
#   'is',
#   'a',
#   'real',
#   'subjective',
#   'question',
#   ',',
#   'but',
#   'i',
#   "'ve",
#   'only',
#   'played',
#   'around',
#   'with',
#   'the',
#   'machines',
#   'in',
#   'a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   'who',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   ')',
#   '.',
#   '*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   '?',
#   ';',
#   ')',
#   'thanks',
#   'a',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   '-',
#   'if',
#   'you',
#   'could',
#   'email',
#   ',',
#   'i',
#   "'ll",
#   'post',
#   'a',
#   'summary',
#   '(',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the',
#   'corner',
#   '...',
#   ':',
#   '(',
#   ')',
#   '--',
#   'Tom',
#   'Willis',
#   '\\',
#   'twillis',
#   '@',
#   'ecn.purdue.edu',
#   '\\',
#   'Purdue',
#   'Electrical',
#   'Engineering'))

# %% [markdown]
# If you have a pre-build NLP model (from Spacy, Stanza, or NLTK) you can pass those in to replace the defaults. For example

# %%
my_nlp = nltk.tokenize.SpaceTokenizer()
tokens = textmap.tokenizers.NLTKTokenizer(nlp = my_nlp).fit_transform(data)
tokens[0:3]
# Out:
# (('i',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'i',
#   'saw\nthe',
#   'other',
#   'day.',
#   'it',
#   'was',
#   'a',
#   '2-door',
#   'sports',
#   'car,',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s/\nearly',
#   '70s.',
#   'it',
#   'was',
#   'called',
#   'a',
#   'bricklin.',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small.',
#   'in',
#   'addition,\nthe',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body.',
#   'this',
#   'is',
#   '\nall',
#   'i',
#   'know.',
#   'if',
#   'anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name,',
#   'engine',
#   'specs,',
#   'years\nof',
#   'production,',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made,',
#   'history,',
#   'or',
#   'whatever',
#   'info',
#   'you\nhave',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car,',
#   'please',
#   'e-mail.'),
#  ('a',
#   'fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have\nshared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll.',
#   'please',
#   'send',
#   'a',
#   'brief',
#   'message',
#   'detailing\nyour',
#   'experiences',
#   'with',
#   'the',
#   'procedure.',
#   'top',
#   'speed',
#   'attained,',
#   'cpu',
#   'rated',
#   'speed,\nadd',
#   'on',
#   'cards',
#   'and',
#   'adapters,',
#   'heat',
#   'sinks,',
#   'hour',
#   'of',
#   'usage',
#   'per',
#   'day,',
#   'floppy',
#   'disk\nfunctionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested.\n\ni',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two',
#   'days,',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network\nknowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   "haven't",
#   'answered',
#   'this\npoll.',
#   'thanks.'),
#  ('well',
#   'folks,',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after\nstarting',
#   'life',
#   'as',
#   'a',
#   '512k',
#   'way',
#   'back',
#   'in',
#   '1985.',
#   '',
#   'sooo,',
#   "i'm",
#   'in',
#   'the',
#   'market',
#   'for',
#   'a\nnew',
#   'machine',
#   'a',
#   'bit',
#   'sooner',
#   'than',
#   'i',
#   'intended',
#   'to',
#   "be...\n\ni'm",
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'a',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'a',
#   'bunch\nof',
#   'questions',
#   'that',
#   '(hopefully)',
#   'somebody',
#   'can',
#   'answer:\n\n*',
#   'does',
#   'anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook\nintroductions',
#   'are',
#   'expected?',
#   '',
#   "i'd",
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an\nappearence',
#   '"this',
#   'summer"',
#   'but',
#   "haven't",
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   '-',
#   'and',
#   'since',
#   "i\ndon't",
#   'have',
#   'access',
#   'to',
#   'macleak,',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had\nmore',
#   'info...\n\n*',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the\nones',
#   'the',
#   "duo's",
#   'just',
#   'went',
#   'through',
#   'recently?\n\n*',
#   "what's",
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180?',
#   '',
#   'i',
#   'could',
#   'probably',
#   'swing\na',
#   '180',
#   'if',
#   'i',
#   'got',
#   'the',
#   '80mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120,',
#   'but',
#   'i',
#   "don't",
#   'really',
#   'have\na',
#   'feel',
#   'for',
#   'how',
#   'much',
#   '"better"',
#   'the',
#   'display',
#   'is',
#   '(yea,',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the\nstore,',
#   'but',
#   'is',
#   'that',
#   'all',
#   '"wow"',
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good?).',
#   '',
#   'could',
#   'i',
#   'solicit\nsome',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day-to-day',
#   'on',
#   'if',
#   'its',
#   'worth\ntaking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display?',
#   '',
#   '(i',
#   'realize\nthis',
#   'is',
#   'a',
#   'real',
#   'subjective',
#   'question,',
#   'but',
#   "i've",
#   'only',
#   'played',
#   'around',
#   'with',
#   'the\nmachines',
#   'in',
#   'a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody\nwho',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful).\n\n*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform?',
#   '',
#   ';)\n\nthanks',
#   'a',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   '-',
#   'if',
#   'you',
#   'could',
#   'email,',
#   "i'll",
#   'post',
#   'a\nsummary',
#   '(news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the\ncorner...',
#   ':(',
#   ')\n--\ntom',
#   'willis',
#   '',
#   '\\',
#   '',
#   'twillis@ecn.purdue.edu',
#   '',
#   '',
#   '',
#   '\\',
#   '',
#   '',
#   '',
#   'purdue',
#   'electrical',
#   'engineering'))

# %%
from spacy.lang.fr import French
tokens = textmap.tokenizers.SpacyTokenizer(nlp = French()).fit_transform(data)
tokens[0:3]
# Out:
# (('i',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'i',
#   'saw',
#   '\n',
#   'the',
#   'other',
#   'day',
#   '.',
#   'it',
#   'was',
#   'a',
#   '2-door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s/',
#   '\n',
#   'early',
#   '70s',
#   '.',
#   'it',
#   'was',
#   'called',
#   'a',
#   'bricklin',
#   '.',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small',
#   '.',
#   'in',
#   'addition',
#   ',',
#   '\n',
#   'the',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body',
#   '.',
#   'this',
#   'is',
#   '\n',
#   'all',
#   'i',
#   'know',
#   '.',
#   'if',
#   'anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name',
#   ',',
#   'engine',
#   'specs',
#   ',',
#   'years',
#   '\n',
#   'of',
#   'production',
#   ',',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   ',',
#   'history',
#   ',',
#   'or',
#   'whatever',
#   'info',
#   'you',
#   '\n',
#   'have',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car',
#   ',',
#   'please',
#   'e-mail',
#   '.'),
#  ('a',
#   'fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have',
#   '\n',
#   'shared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll',
#   '.',
#   'please',
#   'send',
#   'a',
#   'brief',
#   'message',
#   'detailing',
#   '\n',
#   'your',
#   'experiences',
#   'with',
#   'the',
#   'procedure',
#   '.',
#   'top',
#   'speed',
#   'attained',
#   ',',
#   'cpu',
#   'rated',
#   'speed',
#   ',',
#   '\n',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   ',',
#   'heat',
#   'sinks',
#   ',',
#   'hour',
#   'of',
#   'usage',
#   'per',
#   'day',
#   ',',
#   'floppy',
#   'disk',
#   '\n',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   '.',
#   '\n\n',
#   'i',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two',
#   'days',
#   ',',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network',
#   '\n',
#   'knowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   "haven'",
#   't',
#   'answered',
#   'this',
#   '\n',
#   'poll',
#   '.',
#   'thanks',
#   '.'),
#  ('well',
#   'folks',
#   ',',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   '\n',
#   'starting',
#   'life',
#   'as',
#   'a',
#   '512k',
#   'way',
#   'back',
#   'in',
#   '1985',
#   '.',
#   ' ',
#   'sooo',
#   ',',
#   "i'",
#   'm',
#   'in',
#   'the',
#   'market',
#   'for',
#   'a',
#   '\n',
#   'new',
#   'machine',
#   'a',
#   'bit',
#   'sooner',
#   'than',
#   'i',
#   'intended',
#   'to',
#   'be',
#   '...',
#   '\n\n',
#   "i'",
#   'm',
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'a',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'a',
#   'bunch',
#   '\n',
#   'of',
#   'questions',
#   'that',
#   '(',
#   'hopefully',
#   ')',
#   'somebody',
#   'can',
#   'answer',
#   ':',
#   '\n\n',
#   '*',
#   'does',
#   'anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   '\n',
#   'introductions',
#   'are',
#   'expected',
#   '?',
#   ' ',
#   "i'",
#   'd',
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an',
#   '\n',
#   'appearence',
#   '"',
#   'this',
#   'summer',
#   '"',
#   'but',
#   "haven'",
#   't',
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   '-',
#   'and',
#   'since',
#   'i',
#   '\n',
#   "don'",
#   't',
#   'have',
#   'access',
#   'to',
#   'macleak',
#   ',',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had',
#   '\n',
#   'more',
#   'info',
#   '...',
#   '\n\n',
#   '*',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the',
#   '\n',
#   'ones',
#   'the',
#   "duo'",
#   's',
#   'just',
#   'went',
#   'through',
#   'recently',
#   '?',
#   '\n\n',
#   '*',
#   "what'",
#   's',
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180',
#   '?',
#   ' ',
#   'i',
#   'could',
#   'probably',
#   'swing',
#   '\n',
#   'a',
#   '180',
#   'if',
#   'i',
#   'got',
#   'the',
#   '80mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120',
#   ',',
#   'but',
#   'i',
#   "don'",
#   't',
#   'really',
#   'have',
#   '\n',
#   'a',
#   'feel',
#   'for',
#   'how',
#   'much',
#   '"',
#   'better',
#   '"',
#   'the',
#   'display',
#   'is',
#   '(',
#   'yea',
#   ',',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the',
#   '\n',
#   'store',
#   ',',
#   'but',
#   'is',
#   'that',
#   'all',
#   '"',
#   'wow',
#   '"',
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good',
#   '?',
#   ')',
#   '.',
#   ' ',
#   'could',
#   'i',
#   'solicit',
#   '\n',
#   'some',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day',
#   '-',
#   'to',
#   '-',
#   'day',
#   'on',
#   'if',
#   'its',
#   'worth',
#   '\n',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display',
#   '?',
#   ' ',
#   '(',
#   'i',
#   'realize',
#   '\n',
#   'this',
#   'is',
#   'a',
#   'real',
#   'subjective',
#   'question',
#   ',',
#   'but',
#   "i'",
#   've',
#   'only',
#   'played',
#   'around',
#   'with',
#   'the',
#   '\n',
#   'machines',
#   'in',
#   'a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   '\n',
#   'who',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   ')',
#   '.',
#   '\n\n',
#   '*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   '?',
#   ' ',
#   ';)',
#   '\n\n',
#   'thanks',
#   'a',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   '-',
#   'if',
#   'you',
#   'could',
#   'email',
#   ',',
#   "i'",
#   'll',
#   'post',
#   'a',
#   '\n',
#   'summary',
#   '(',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the',
#   '\n',
#   'corner',
#   '...',
#   ':(',
#   ')',
#   '\n',
#   '--',
#   '\n',
#   'tom',
#   'willis',
#   ' ',
#   '\\',
#   ' ',
#   'twillis@ecn.purdue.edu',
#   '   ',
#   '\\',
#   '   ',
#   'purdue',
#   'electrical',
#   'engineering'))

# %% [markdown]
# You can pass any tokenizer an instance of any class that you would like, as long as it has the same basic functionality.  For example, the NLTK tokenizer can accept any class that has a tokenize function.

# %%
class SillyNLP():
    
    def tokenize(self, X):
        if len(X) % 5 == 4: 
            return ["Badger"]*(len(X) // 10 ) + ['aghh', 'Snake', 'A', 'Snake', 'Ooooh', 'Its', 'A', 'Snake']
        return ["Badger"]*(len(X) // 10 ) + ['mushroom', 'mushroom']

# %%
silly_tokens = textmap.tokenizers.NLTKTokenizer(nlp = SillyNLP()).fit_transform(data)
silly_tokens[0:3]
# Out:
# (('badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'mushroom',
#   'mushroom'),
#  ('badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'mushroom',
#   'mushroom'),
#  ('badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'badger',
#   'aghh',
#   'snake',
#   'a',
#   'snake',
#   'ooooh',
#   'its',
#   'a',
#   'snake'))

# %%
silly_tokens = textmap.tokenizers.NLTKTokenizer(nlp = SillyNLP(), lower_case = False).fit_transform(data)
silly_tokens[0:3]
# Out:
# (('Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'mushroom',
#   'mushroom'),
#  ('Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'mushroom',
#   'mushroom'),
#  ('Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'Badger',
#   'aghh',
#   'Snake',
#   'A',
#   'Snake',
#   'Ooooh',
#   'Its',
#   'A',
#   'Snake'))

# %% [markdown]
# ## Multi-token expressions:

# %% [markdown]
# Now we may wish to contract common n-grams into a single token to cature common phrases as a single token.  By default this computes the likelihood ratio of the actual number of times a pair of tokens are adjacent over the likelihood under independence (the product of thier frequencies).  If a pair of tokens is occurs more then 2^7 times more often together than expected under independence then the occurrences of adjacent pairs are contracted to a single token.  It then repeats this process again on the contracted text (default is on more time) to potentially contract larger n-grams.
#
# (This class relies heavily on the NLTK MultiWordExpression infrastructure which is quite excellent)

# %%
mte = textmap.transformers.MultiTokenExpressionTransformer()
new_tokens = mte.fit_transform(tokens)

# %% [markdown]
# For reproducibility, the model stores the multi-token expressions as a list of pairs of tokens to contract per iteration.

# %%
mte.mtes_
# Out:
# [[('_', '_'),
#   ("don'", 't'),
#   ("it'", 's'),
#   ("i'", 'm'),
#   ('of', 'the'),
#   ('in', 'the'),
#   ('i', 'am'),
#   ('if', 'you'),
#   ("i'", 've'),
#   ("can'", 't'),
#   ('it', 'is'),
#   ("didn'", 't'),
#   ("doesn'", 't'),
#   ('to', 'be'),
#   ("that'", 's'),
#   ('on', 'the'),
#   ('i', 'have'),
#   ('i', "don'"),
#   ("you'", 're'),
#   ('i', 'think'),
#   ('would', 'be'),
#   ('will', 'be'),
#   ('at', 'least'),
#   ('have', 'been'),
#   ('the', 'same'),
#   ('this', 'is'),
#   ("isn'", 't'),
#   ("i'", 'd'),
#   ('there', 'are'),
#   ('the', 'the'),
#   ('there', 'is'),
#   ('has', 'been'),
#   ('want', 'to'),
#   ('you', 'can'),
#   ('does', 'not'),
#   ("i'", 'll'),
#   ('they', 'are'),
#   ("there'", 's'),
#   ('a', 'lot'),
#   ('a', 'few'),
#   ('is', 'not'),
#   ('can', 'be'),
#   ('should', 'be'),
#   ('is', 'a'),
#   ('going', 'to'),
#   ("they'", 're'),
#   ('able', 'to'),
#   ("won'", 't'),
#   ('it', 'was'),
#   ('do', 'not'),
#   ('of', 'course'),
#   ("wouldn'", 't'),
#   ('united', 'states'),
#   ('t', 'know'),
#   ('to', 'get'),
#   ("we'", 're'),
#   ('may', 'be'),
#   ('from', 'the'),
#   ('i', 'would'),
#   ('they', 'were'),
#   ('to', 'do'),
#   ('more', 'than'),
#   ('you', 'are'),
#   ('as', 'well'),
#   ('for', 'the'),
#   ("he'", 's'),
#   ('have', 'a'),
#   ('trying', 'to'),
#   ('the', 'to'),
#   ('new', 'york'),
#   ('but', 'i'),
#   ('you', 'have'),
#   ("let'", 's'),
#   ("haven'", 't'),
#   ("aren'", 't'),
#   ('such', 'as'),
#   ('number', 'of'),
#   ('out', 'of'),
#   ('be', 'able'),
#   ('at', 'the'),
#   ("couldn'", 't'),
#   ('with', 'the'),
#   ("wasn'", 't'),
#   ('the', 'of'),
#   ('people', 'who'),
#   ('the', 'first'),
#   ("what'", 's'),
#   ('those', 'who'),
#   ('as', 'a'),
#   ('based', 'on'),
#   ('los', 'angeles'),
#   ('he', 'was'),
#   ('part', 'of'),
#   ('one', 'of'),
#   ('do', 'you'),
#   ('must', 'be'),
#   ('for', 'example'),
#   ('rather', 'than'),
#   ('a', 'the'),
#   ('kind', 'of'),
#   ('i', 'can'),
#   ('to', 'make'),
#   ('does', 'anyone'),
#   ('lot', 'of'),
#   ('the', 'following'),
#   ('by', 'the'),
#   ('the', 'a'),
#   ('with', 'a'),
#   ('for', 'a'),
#   ('i', 'know'),
#   ('anonymous', 'ftp'),
#   ('years', 'ago'),
#   ('law', 'enforcement'),
#   ('need', 'to'),
#   ('i', 'was'),
#   ('seem', 'to'),
#   ('look', 'at'),
#   ('a', 'good'),
#   ("you'", 'll'),
#   ('you', 'want'),
#   ('in', 'advance'),
#   ('we', 'have'),
#   ('looking', 'for'),
#   ('tell', 'me'),
#   ("god'", 's'),
#   ('let', 'me'),
#   ('did', 'not'),
#   ('what', 'is'),
#   ('m', 'not'),
#   ('might', 'be'),
#   ('to', 'the'),
#   ('interested', 'in'),
#   ('seems', 'to'),
#   ('that', 'the'),
#   ('when', 'i'),
#   ('a', 'little'),
#   ('it', 'seems'),
#   ('which', 'is'),
#   ('would', 'like'),
#   ('that', 'they'),
#   ('sort', 'of'),
#   ('clipper', 'chip'),
#   ('the', 'in'),
#   ('the', 'bible'),
#   ('could', 'be'),
#   ('a', 'couple'),
#   ('would', 'have'),
#   ('their', 'own'),
#   ('we', 'are'),
#   ('the', 'is'),
#   ('according', 'to'),
#   ('talking', 'about'),
#   ('have', 'to'),
#   ('t', 'have'),
#   ('to', 'use'),
#   ('i', 'believe'),
#   ('for', 'sale'),
#   ('last', 'year'),
#   ('in', 'fact'),
#   ("we'", 'll'),
#   ('try', 'to'),
#   ('i', 'the'),
#   ('say', 'that'),
#   ('the', 'i'),
#   ('san', 'francisco'),
#   ('are', 'not'),
#   ('fact', 'that'),
#   ('i', "can'"),
#   ('the', 'that'),
#   ('in', 'a'),
#   ('believe', 'that'),
#   ("you'", 've'),
#   ("shouldn'", 't'),
#   ('serdar', 'argic'),
#   ('thank', 'you'),
#   ('had', 'been'),
#   ('a', 'bit'),
#   ('at', 'all'),
#   ('windows', '3.1'),
#   ('to', 'see'),
#   ('willing', 'to'),
#   ('san', 'jose'),
#   ('t', 'think'),
#   ('due', 'to'),
#   ('be', 'used'),
#   ('to', 'to'),
#   ('far', 'as'),
#   ('hard', 'disk'),
#   ('ve', 'been'),
#   ('it', 'would'),
#   ('like', 'to'),
#   ('your', 'own'),
#   ('less', 'than'),
#   ('into', 'the'),
#   ('couple', 'of'),
#   ('no', 'longer'),
#   ('if', 'they'),
#   ('you', 'know'),
#   ('as', 'far'),
#   ('of', 'these'),
#   ('to', 'of'),
#   ("here'", 's'),
#   ('a', 'new'),
#   ('in', 'order'),
#   ('know', 'what'),
#   ('of', 'to'),
#   ("you'", 'd'),
#   ('note', 'that'),
#   ('the', 'best'),
#   ('the', 'other'),
#   ('how', 'do'),
#   ('ve', 'seen'),
#   ('d', 'like'),
#   ('used', 'to'),
#   ('how', 'much'),
#   ('that', 'he'),
#   ('to', 'me'),
#   ('to', 'keep'),
#   ('and', 'then'),
#   ('there', 'were'),
#   ('gordon', 'banks'),
#   ('is', 'no'),
#   ('to', 'take'),
#   ('about', 'the'),
#   ('think', 'that'),
#   ('instead', 'of'),
#   ('there', 'was'),
#   ('such', 'a'),
#   ('most', 'of'),
#   ('the', 'second'),
#   ('ve', 'got'),
#   ('to', 'say'),
#   ('mailing', 'list'),
#   ('a', 'to'),
#   ('power', 'play'),
#   ('you', "don'"),
#   ('even', 'if'),
#   ('anyone', 'know'),
#   ('the', 'rest'),
#   ('to', 'go'),
#   ('i', 'guess'),
#   ('i', 'do'),
#   ('hard', 'drive'),
#   ("we'", 've'),
#   ('they', 'have'),
#   ('to', 'find'),
#   ('university', 'of'),
#   ('other', 'hand'),
#   ('out', 'there'),
#   ('i', 'had'),
#   ('of', 'of'),
#   ('how', 'many'),
#   ('we', 'can'),
#   ('i', 'need'),
#   ('end', 'of'),
#   ('difference', 'between'),
#   ('any', 'other'),
#   ('the', 'for'),
#   ('so', 'far'),
#   ('i', 'thought'),
#   ('supposed', 'to'),
#   ('in', 'addition'),
#   ('gun', 'control'),
#   ('the', 'world'),
#   ('on', 'a'),
#   ('the', 'next'),
#   ('something', 'like'),
#   ('m', 'sure'),
#   ('a', 'of'),
#   ('the', 'whole'),
#   ('looks', 'like'),
#   ('i', 'want'),
#   ('am', 'looking'),
#   ('a', 'single'),
#   ('can', 'get'),
#   ('even', 'though'),
#   ('not', 'sure'),
#   ('well', 'as'),
#   ('better', 'than'),
#   ('is', 'that'),
#   ('that', 'you'),
#   ('it', 'has'),
#   ("hasn'", 't'),
#   ('if', 'anyone'),
#   ('in', 'this'),
#   ('lots', 'of'),
#   ('be', 'a'),
#   ('much', 'more'),
#   ('if', "you'"),
#   ('some', 'of'),
#   ('window', 'manager'),
#   ('that', 'it'),
#   ('in', 'my'),
#   ('rest', 'of'),
#   ('white', 'house'),
#   ('too', 'much'),
#   ('very', 'good'),
#   ('the', 'president'),
#   ('but', 'it'),
#   ('to', 'and'),
#   ('the', 'fact'),
#   ('st.', 'louis'),
#   ('i', 'hope'),
#   ('of', 'and'),
#   ('set', 'up'),
#   ('has', 'a'),
#   ('make', 'sure'),
#   ('the', 'united'),
#   ('was', 'a'),
#   ('he', 'said'),
#   ('that', 'there'),
#   ('when', 'they'),
#   ('said', 'that'),
#   ('if', 'i'),
#   ('the', 'problem'),
#   ('i', 'will'),
#   ("one'", 's'),
#   ('is', 'an'),
#   ('the', 'way'),
#   ('wanted', 'to'),
#   ('p.o.', 'box'),
#   ('what', 'i'),
#   ('a', 'very'),
#   ('up', 'to'),
#   ('serial', 'number'),
#   ('the', 'you'),
#   ('the', 'most'),
#   ('amount', 'of'),
#   ('the', 'last'),
#   ('because', 'they'),
#   ('know', 'if'),
#   ('and', 'and'),
#   ('that', 'i'),
#   ('way', 'to'),
#   ('of', 'a'),
#   ('you', 'think'),
#   ('order', 'to'),
#   ('during', 'the'),
#   ('other', 'than'),
#   ('a', 'a'),
#   ('t', 'want'),
#   ('have', 'any'),
#   ('a', 'and'),
#   ('greatly', 'appreciated'),
#   ('you', 'need'),
#   ('find', 'out'),
#   ('you', 'should'),
#   ('the', 'original'),
#   ('had', 'a'),
#   ('health', 'care'),
#   ('that', 'is'),
#   ('not', 'be'),
#   ('he', 'has'),
#   ('of', 'this'),
#   ('it', 'the'),
#   ('of', 'them'),
#   ('who', 'are'),
#   ('enough', 'to'),
#   ('no', 'one'),
#   ('i', "haven'"),
#   ("they'", 've'),
#   ('get', 'a'),
#   ('i', 'saw'),
#   ('lack', 'of'),
#   ('it', 'will'),
#   ('i', 'could'),
#   ('please', 'send'),
#   ('am', 'not'),
#   ('how', 'to'),
#   ("they'", 'll'),
#   ('available', 'from'),
#   ('you', 'may'),
#   ('the', 'right'),
#   ('when', 'you'),
#   ('back', 'to'),
#   ("weren'", 't'),
#   ('have', 'no'),
#   ('over', 'the'),
#   ('second', 'amendment'),
#   ('deal', 'with'),
#   ('that', 'we'),
#   ('agree', 'with'),
#   ('et', 'al'),
#   ('2', '2'),
#   ('version', 'of'),
#   ('the', 'this'),
#   ('will', 'not'),
#   ('on', 'my'),
#   ('he', 'had'),
#   ('if', 'it'),
#   ('the', 'net'),
#   ('apr', '93'),
#   ('may', 'have'),
#   ('hicnet', 'medical'),
#   ('my', 'own'),
#   ('along', 'with'),
#   ('on', 'this'),
#   ('best', 'offer'),
#   ('the', 'end'),
#   ('the', 'only'),
#   ('anyone', 'else'),
#   ('s', 'not'),
#   ('you', 'could'),
#   ('it', "doesn'"),
#   ('the', 'be'),
#   ('long', 'as'),
#   ('the', 'on'),
#   ('you', "can'"),
#   ('holy', 'spirit'),
#   ('pointed', 'out'),
#   ('because', 'of'),
#   ("people'", 's'),
#   ('so', 'i'),
#   ('many', 'people'),
#   ('thanks', 'in'),
#   ('all', 'the'),
#   ('associated', 'with'),
#   ('in', 'of'),
#   ('know', 'how'),
#   ('you', 'might'),
#   ('i', 'get'),
#   ('any', 'help'),
#   ('to', 'i'),
#   ('to', 'in'),
#   ('some', 'sort'),
#   ('may', 'not'),
#   ('they', 'had'),
#   ('stuff', 'deleted'),
#   ('to', 'is'),
#   ('all', 'of'),
#   ('san', 'diego'),
#   ('i', 'got'),
#   ('i', "didn'"),
#   ('right', 'now'),
#   ('tampa', 'bay'),
#   ('depending', 'on'),
#   ('bear', 'arms'),
#   ('rom', 'bios'),
#   ('the', 'new'),
#   ("brind'", 'amour'),
#   ('away', 'from'),
#   ('likely', 'to'),
#   ('saying', 'that'),
#   ('as', 'an'),
#   ('via', 'anonymous'),
#   ('public', 'domain'),
#   ('tend', 'to'),
#   ('the', 'u.s.'),
#   ('figure', 'out'),
#   ('available', 'via'),
#   ('to', 'give'),
#   ('i', 'to'),
#   ('told', 'me'),
#   ('give', 'me'),
#   ('looking', 'at'),
#   ('after', 'all'),
#   ('when', 'he'),
#   ('re', 'going'),
#   ('of', 'i'),
#   ('wondering', 'if'),
#   ('stanley', 'cup'),
#   ('i', 'agree'),
#   ('i', 'just'),
#   ('the', 'are'),
#   ('through', 'the'),
#   ('of', 'god'),
#   ('each', 'other'),
#   ('a', 'small'),
#   ('its', 'own'),
#   ('power', 'supply'),
#   ('to', 'have'),
#   ('medical', 'newsletter'),
#   ('so', 'that'),
#   ('come', 'up'),
#   ('tried', 'to'),
#   ('the', 'with'),
#   ('of', 'in'),
#   ('a', 'in'),
#   ('the', 'government'),
#   ('talk', 'about'),
#   ('the', 'have'),
#   ('human', 'rights'),
#   ('is', 'available'),
#   ('attempt', 'to'),
#   ('few', 'years'),
#   ('a', 'copy'),
#   ('good', 'luck'),
#   ('i', 'of'),
#   ('they', 'will'),
#   ('to', 'pay'),
#   ('video', 'card'),
#   ('the', 'above'),
#   ('what', 'you'),
#   ('up', 'with'),
#   ('as', 'long'),
#   ('problem', 'with'),
#   ('of', 'is'),
#   ('more', 'likely'),
#   ('the', 'not'),
#   ('access', 'to'),
#   ('know', 'that'),
#   ('and', 'i'),
#   ('this', 'group'),
#   ('if', 'there'),
#   ('senior', 'administration'),
#   ('a', 'number'),
#   ('a', 'great'),
#   ('a', 'i'),
#   ('local', 'bus'),
#   ('information', 'about'),
#   ('sure', 'that'),
#   ('sounds', 'like'),
#   ('m', 'looking'),
#   ('these', 'are'),
#   ('ve', 'heard'),
#   ('someone', 'else'),
#   ('i', 'a'),
#   ('as', 'i'),
#   ('use', 'of'),
#   ('send', 'me'),
#   ('you', 'will'),
#   ('the', 'as'),
#   ('his', 'own'),
#   ('responsible', 'for'),
#   ('to', 'protect'),
#   ('a', 'large'),
#   ('make', 'it'),
#   ('information', 'on'),
#   ('but', "i'"),
#   ('weeks', 'ago'),
#   ('2.5', 'million'),
#   ('new', 'jersey'),
#   ('to', 'work'),
#   ('for', 'instance'),
#   ('it', 'does'),
#   ('too', 'soon'),
#   ('this', 'the'),
#   ('source', 'code'),
#   ('in', 'their'),
#   ('jesus', 'christ'),
#   ('what', 'they'),
#   ('a', 'is'),
#   ('ll', 'be'),
#   ('the', 't'),
#   ('you', 'mean'),
#   ('depends', 'on'),
#   ('you', 'the'),
#   ('how', 'can'),
#   ('t', 'see'),
#   ('assume', 'that'),
#   ("he'", 'll'),
#   ('can', 'do'),
#   ('a', 'that'),
#   ('he', 'is'),
#   ('same', 'thing'),
#   ('no', 'matter'),
#   ('cannot', 'be'),
#   ('list', 'of'),
#   ('so', 'much'),
#   ('the', 'or'),
#   ('t', 'get'),
#   ('a', 'bunch'),
#   ('this', 'year'),
#   ('the', 'armenians'),
#   ('very', 'much'),
#   ('maple', 'leafs'),
#   ('anyone', 'who'),
#   ('a', 'problem'),
#   ('and', 'of'),
#   ('please', 'reply'),
#   ('the', 's'),
#   ("today'", 's'),
#   ('once', 'again'),
#   ('would', 'not'),
#   ('because', 'it'),
#   ('of', 'their'),
#   ('i', 'suspect'),
#   ('of', 'his'),
#   ('to', 'avoid'),
#   ('to', 'buy'),
#   ('the', 'entire'),
#   ('the', 'law'),
#   ('the', 'fbi'),
#   ('was', 'wondering'),
#   ('the', '_'),
#   ('t', 'be'),
#   ('april', '20'),
#   ('are', 'available'),
#   ('thousands', 'of'),
#   ('mean', 'that'),
#   ("o'", 'reilly'),
#   ('copy', 'of'),
#   ('please', 'e-mail'),
#   ('variety', 'of'),
#   ('under', 'the'),
#   ('should', 'have'),
#   ('as', 'much'),
#   ('the', 'past'),
#   ('has', 'anyone'),
#   ('ftp', 'site'),
#   ('or', 'not'),
#   ('do', 'with'),
#   ('image', 'processing'),
#   ('my', 'opinion'),
#   ('a', 'friend'),
#   ('administration', 'official'),
#   ('have', 'seen'),
#   ('some', 'people'),
#   ('is', 'there'),
#   ('and', 'other'),
#   ('followed', 'by'),
#   ('capable', 'of'),
#   ('bunch', 'of'),
#   ('members', 'of'),
#   ('thanks', 'for'),
#   ('wants', 'to'),
#   ('ability', 'to'),
#   ('make', 'a'),
#   ('but', 'not'),
#   ('if', 'we'),
#   ('in', 'to'),
#   ('the', 'current'),
#   ('other', 'words'),
#   ('curt', 'noll'),
#   ('is', 'and'),
#   ('last', 'night'),
#   ('to', 'build'),
#   ('problem', 'is'),
#   ('to', 'know'),
#   ('help', 'me'),
#   ('kinds', 'of'),
#   ('continue', 'to'),
#   ('cross', 'linked'),
#   ('know', 'about'),
#   ('_', 'the'),
#   ('t', 'even'),
#   ('landon', 'curt'),
#   ('to', 'put'),
#   ('tear', 'gas'),
#   ('only', 'one'),
#   ('for', 'to'),
#   ('unless', 'you'),
#   ('we', 'were'),
#   ('in', 'his'),
#   ('to', 'run'),
#   ('allocation', 'unit'),
#   ('the', 'time'),
#   ('s', 'a'),
#   ('too', 'many'),
#   ('the', 'latest'),
#   ('claim', 'that'),
#   ('space', 'station'),
#   ('please', 'email'),
#   ('and', 'the'),
#   ('involved', 'in'),
#   ('pretty', 'good'),
#   ('i', 'heard'),
#   ('not', 'have'),
#   ('does', 'anybody'),
#   ('problems', 'with'),
#   ('go', 'to'),
#   ('like', 'a'),
#   ('someone', 'who'),
#   ('of', 'those'),
#   ('pay', 'for'),
#   ('disk', 'drives'),
#   ('we', 'need'),
#   ('easy', 'to'),
#   ('about', 'it'),
#   ('floppy', 'disk'),
#   ('is', 'also'),
#   ('coli', 'o157'),
#   ('i', 'and'),
#   ('to', 'create'),
#   ('to', 'for'),
#   ('have', 'an'),
#   ('smokeless', 'tobacco'),
#   ('of', 'our'),
#   ('months', 'ago'),
#   ('not', 'necessarily'),
#   ('in', 'general'),
#   ('i', 'bought'),
#   ('tell', 'you'),
#   ('set', 'of'),
#   ('excellent', 'condition'),
#   ('cape', 'breton'),
#   ("who'", 's'),
#   ('unable', 'to'),
#   ('a', 'big'),
#   ('last', 'week'),
#   ('is', 'shameful'),
#   ('wish', 'to'),
#   ('compared', 'to'),
#   ('into', 'a'),
#   ('tell', 'us'),
#   ('the', 'if'),
#   ('third', 'period'),
#   ('they', "didn'"),
#   ('who', 'have'),
#   ('who', 'were'),
#   ('skepticism', 'is'),
#   ('be', 'done'),
#   ('person', 'who'),
#   ('first', 'place'),
#   ('brand', 'new'),
#   ('soviet', 'union'),
#   ('works', 'fine'),
#   ('going', 'on'),
#   ('i', 'remember'),
#   ('faster', 'than'),
#   ('they', 'can'),
#   ('get', 'rid'),
#   ('they', 'the'),
#   ('live', 'in'),
#   ('of', 'my'),
#   ('virtual', 'reality'),
#   ('or', 'something'),
#   ('space', 'shuttle'),
#   ('t', 'work'),
#   ('the', 'main'),
#   ('cubs', 'suck'),
#   ('regardless', 'of'),
#   ('they', 'would'),
#   ('to', 'provide'),
#   ('public', 'key'),
#   ('none', 'of'),
#   ('he', 'says'),
#   ('or', 'so'),
#   ('chastity', 'of'),
#   ('a', 'long'),
#   ('ghost', 'rider'),
#   ('top', 'of'),
#   ('the', 'they'),
#   ('will', 'have'),
#   ('working', 'on'),
#   ('we', "don'"),
#   ('some', 'kind'),
#   ('in', 'your'),
#   ('was', 'not'),
#   ('i', 'find'),
#   ('remote', 'sensing'),
#   ('we', 'should'),
#   ('first', 'time'),
#   ('when', 'the'),
#   ('world', 'war'),
#   ('ottoman', 'empire'),
#   ('is', 'still'),
#   ('rid', 'of'),
#   ('the', 'turkish'),
#   ('i', 'mean'),
#   ("she'", 's'),
#   ('come', 'to'),
#   ("qur'", 'an'),
#   ('is', 'going'),
#   ('must', 'have'),
#   ('you', 'do'),
#   ('year', 'old'),
#   ('know', 'where'),
#   ('there', 'any'),
#   ('surrender', 'it'),
#   ('is', 'of'),
#   ('a', 'it'),
#   ('the', 'idea'),
#   ('it', 'may'),
#   ('comes', 'with'),
#   ('any', 'suggestions'),
#   ('can', 'use'),
#   ('long', 'time'),
#   ('much', 'better'),
#   ('what', 'happens'),
#   ('it', 'of'),
#   ('d', 'be'),
#   ('red', 'sox'),
#   ('email', 'address'),
#   ('the', 'word'),
#   ('same', 'time'),
#   ('right', 'to'),
#   ('refer', 'to'),
#   ('is', 'true'),
#   ('of', 'for'),
#   ('about', 'this'),
#   ('the', 'by'),
#   ('caused', 'by'),
#   ('mb', 'ram'),
#   ('tape', 'drive'),
#   ('department', 'of'),
#   ('i', 'is'),
#   ('believe', 'in'),
#   ('here', 'is'),
#   ('electronic', 'mail'),
#   ('familiar', 'with'),
#   ('why', 'do'),
#   ('he', 'did'),
#   ('they', 'did'),
#   ('you', 'must'),
#   ("john'", 's'),
#   ('that', 'to'),
#   ('point', 'out'),
#   ('a', 'while'),
#   ("hadn'", 't'),
#   ('looked', 'at'),
#   ('ve', 'never'),
#   ('with', 'an'),
#   ('to', 'kill'),
#   ('where', 'can'),
#   ('what', 'happened'),
#   ('to', 'surrender'),
#   ('feel', 'free'),
#   ('red', 'wings'),
#   ('they', 'could'),
#   ('to', 'try'),
#   ("o'", 'clock'),
#   ('as', 'possible'),
#   ('swap', 'file'),
#   ('mailing', 'lists'),
#   ('except', 'for'),
#   ('apr', '1993'),
#   ('the', 'middle'),
#   ('in', 'i'),
#   ('to', 'sell'),
#   ('shameful', 'to'),
#   ('do', 'i'),
#   ('realize', 'that'),
#   ('anyone', 'have'),
#   ('dealing', 'with'),
#   ('against', 'the'),
#   ('controller', 'card'),
#   ('she', 'was'),
#   ('in', 'our'),
#   ('between', 'the'),
#   ('i', 'wonder'),
#   ('after', 'the'),
#   ('st', "john'"),
#   ('he', "didn'"),
#   ('any', 'ideas'),
#   ('anything', 'about'),
#   ('member', 'of'),
#   ('they', "don'"),
#   ('me', 'know'),
#   ('is', 'is'),
#   ('the', 'game'),
#   ('can', 'find'),
#   ('attorney', 'general'),
#   ('i', 'did'),
#   ('new', 'testament'),
#   ('the', 'church'),
#   ('an', 'article'),
#   ('is', 'the'),
#   ("they'", 'd'),
#   ('federal', 'government'),
#   ('please', 'let'),
#   ('south', 'georgia'),
#   ('in', 'in'),
#   ('david', 'koresh'),
#   ('second', 'period'),
#   ('no', 'way'),
#   ('a', 'for'),
#   ('existence', 'of'),
#   ('but', 'they'),
#   ('it', 'looks'),
#   ('majority', 'of'),
#   ('vice', 'president'),
#   ('one', 'thing'),
#   ('re', 'not'),
#   ('you', 'get'),
#   ('do', 'it'),
#   ('t', 'believe'),
#   ('onur', 'yalcin'),
#   ('hundreds', 'of'),
#   ('private', 'sector'),
#   ('t', 'seem'),
#   ('on', 'top'),
#   ('civil', 'rights'),
#   ('windows', 'nt'),
#   ('the', 'question'),
#   ('send', 'requests'),
#   ('could', 'have'),
#   ('to', 'help'),
#   ('the', 'from'),
#   ('result', 'of'),
#   ('worry', 'about'),
#   ('that', 'and'),
#   ('me', 'that'),
#   ('type', 'of'),
#   ('are', 'interested'),
#   ('in', 'is'),
#   ('the', 'case'),
#   ('think', "it'"),
#   ('this', 'newsgroup'),
#   ('water', 'dept'),
#   ('the', 'puck'),
#   ('they', 'do'),
#   ('suck', 'cubs'),
#   ('to', 'ask'),
#   ('be', 'appreciated'),
#   ('to', 'come'),
#   ('how', 'about'),
#   ('0', '0.00'),
#   ('piece', 'of'),
#   ('we', 'will'),
#   ('who', 'has'),
#   ('human', 'beings'),
#   ('are', 'you'),
#   ('radar', 'detector'),
#   ('for', 'those'),
#   ('kansas', 'city'),
#   ('i', "wouldn'"),
#   ('or', 'whatever'),
#   ('to', 'prevent'),
#   ('buy', 'a'),
#   ('than', 'the'),
#   ('hockey', 'league'),
#   ('x', 'server'),
#   ("apple'", 's'),
#   ('come', 'out'),
#   ('any', 'info'),
#   ('every', 'day'),
#   ('larry', 'bassel'),
#   ('it', 'works'),
#   ('parts', 'of'),
#   ('my', 'wife'),
#   ('hard', 'to'),
#   ('very', 'well'),
#   ('your', 'entry'),
#   ('question', 'is'),
#   ('use', 'the'),
#   ('designed', 'to'),
#   ('an', 'example'),
#   ('whether', 'or'),
#   ('years', 'old'),
#   ('who', 'knows'),
#   ('anything', 'else'),
#   ('a', 'person'),
#   ('aware', 'of'),
#   ('i', 'said'),
#   ('idea', 'of'),
#   ('be', 'greatly'),
#   ('like', 'this'),
#   ('if', 'he'),
#   ('check', 'out'),
#   ('that', 'this'),
#   ('i', 'found'),
#   ('aspects', 'of'),
#   ('would', 'appreciate'),
#   ('work', 'with'),
#   ('the', 'an'),
#   ('decided', 'to'),
#   ('means', 'that'),
#   ('pick', 'up'),
#   ('can', 'anyone'),
#   ('opposed', 'to'),
#   ('to', 'live'),
#   ('to', 'hear'),
#   ('the', 'truth'),
#   ('pretty', 'much'),
#   ('new', 'zealand'),
#   ('went', 'to'),
#   ('email', 'me'),
#   ('isbn', '0'),
#   ('something', 'else'),
#   ('are', 'going'),
#   ('a', 'result'),
#   ("president'", 's'),
#   ('at', 'home'),
#   ('radio', 'shack'),
#   ('name', 'of'),
#   ('of', 'us'),
#   ('could', 'not'),
#   ('ftp', 'from'),
#   ('the', 'chastity'),
#   ('a', 'different'),
#   ('think', 'it'),
#   ('on', 'your'),
#   ('this', 'country'),
#   ("g'", 'd'),
#   ('santa', 'barbara'),
#   ('a', 'real'),
#   ('every', 'time'),
#   ('response', 'to'),
#   ('who', 'had'),
#   ('we', 'must'),
#   ('in', 'front'),
#   ('most', 'people'),
#   ('in', 'any'),
#   ('serial', 'port'),
#   ('known', 'as'),
#   ('give', 'you'),
#   ('just', 'as'),
#   ('we', 'do'),
#   ('assuming', 'that'),
#   ('this', 'point'),
#   ('is', 'very'),
#   ('exactly', 'what'),
#   ('this', 'problem'),
#   ('the', 'at'),
#   ('might', 'have'),
#   ('for', 'any'),
#   ('do', 'so'),
#   ('the', 'national'),
#   ('what', 'do'),
#   ...],
#  [('___', '___'),
#   ("i_don'", 't_know'),
#   ('thanks_in', 'advance'),
#   ("i_don'", 't_think'),
#   ("i_don'", 't'),
#   ('i_would', 'like_to'),
#   ('there_is', 'no'),
#   ('on_the', 'other_hand'),
#   ('a_lot', 'of'),
#   ('___', '_'),
#   ('skepticism_is', 'the_chastity'),
#   ('shameful_to', 'surrender_it'),
#   ('surrender_it', 'too_soon'),
#   ('one_of', 'the'),
#   ("if_you'", 're'),
#   ('as_well', 'as'),
#   ('where_can', 'i_get'),
#   ("i'_d", 'like_to'),
#   ("i'_ve", 'seen'),
#   ("i'_m", 'not_sure'),
#   ('by_the', 'way'),
#   ('as_far', 'as_i'),
#   ("i_haven'", 't'),
#   ('a_couple', 'of'),
#   ("i_don'", 't_have'),
#   ("i_can'", 't'),
#   ('i_am', 'looking_for'),
#   ('seems_to', 'be'),
#   ('the_united', 'states'),
#   ('a_number', 'of'),
#   ("i'_m", 'not'),
#   ('in_other', 'words'),
#   ('how_do', 'i'),
#   ("i'_m", 'sure'),
#   ('hicnet_medical', 'newsletter'),
#   ('please_let', 'me_know'),
#   ("i'_ve", 'been'),
#   ('at_the', 'same_time'),
#   ('there_is', 'a'),
#   ("why_don'", 't'),
#   ('in_this', 'case'),
#   ("it_isn'", 't'),
#   ('it_is', 'shameful_to'),
#   ('some_of', 'the'),
#   ("you_can'", 't'),
#   ('hope_this', 'helps'),
#   ('at_the', 'end_of'),
#   ('it_would', 'be'),
#   ("it_doesn'", 't'),
#   ('senior_administration', 'official'),
#   ('2_2', '2_2'),
#   ('at_the', 'time'),
#   ('is_cross', 'linked_on'),
#   ('if_you', 'want_to'),
#   ('linked_on', 'allocation_unit'),
#   ('i_do', 'not'),
#   ('i_have', 'a'),
#   ('but_i', "don'_t"),
#   ('the_chastity', 'of_the'),
#   ("it'_s", 'not'),
#   ('it_is', 'not'),
#   ('the_white', 'house'),
#   ('of_the', 'intellect'),
#   ('if_you', "don'_t"),
#   ('part_of', 'the'),
#   ('at_this', 'point'),
#   ('whether_or', 'not'),
#   ('to', 'a'),
#   ('if_you', 'are_interested'),
#   ('the_number', 'of'),
#   ("i_don'", 't_believe'),
#   ('if_you', 'want'),
#   ('it_seems', 'to_me'),
#   ('and_bear', 'arms'),
#   ("but_it'", 's'),
#   ('or_best', 'offer'),
#   ('this_is', 'a'),
#   ("and_i'", 'll'),
#   ("don'_t", 'know'),
#   ('in_any', 'case'),
#   ('on_the', 'net'),
#   ('would_have', 'been'),
#   ('landon_curt', 'noll'),
#   ('s1_and', 's2'),
#   ('in_the', 'past'),
#   ("it_wasn'", 't'),
#   ('point_of', 'view'),
#   ('if_you', 'have'),
#   ('would_be', 'appreciated'),
#   ('on_the', 'internet'),
#   ('center_for', 'policy_research'),
#   ('some_sort', 'of'),
#   ("but_i'", 'm_not'),
#   ('nothing_to', 'do_with'),
#   ('i_was', 'wondering_if'),
#   ('the_clipper', 'chip'),
#   ("and_i'", 'm'),
#   ('in_the', 'first_place'),
#   ("you_don'", 't'),
#   ("i_don'", 't_see'),
#   ('as_far', 'as'),
#   ('most_of', 'the'),
#   ('there_has', 'been'),
#   ('or_any', 'other'),
#   ('are_there', 'any'),
#   ("but_i'", 'm'),
#   ("don'_t", 'have'),
#   ('cubs_suck', 'cubs_suck'),
#   ('to_be', 'able_to'),
#   ('if_you', 'are'),
#   ('to_find', 'out'),
#   ('for_a', 'while'),
#   ('be_able', 'to'),
#   ("that_it'", 's'),
#   ('out_of', 'context'),
#   ("i'_m", 'looking_for'),
#   ('at_a', 'time'),
#   ('may_not', 'be'),
#   ('a_friend', 'of_mine'),
#   ("i_didn'", 't'),
#   ("if_it'", 's'),
#   ('as_i', 'know'),
#   ('it_will', 'be'),
#   ('that_it', 'is'),
#   ('in_my', 'opinion'),
#   ('a_great', 'deal'),
#   ('in_order', 'to'),
#   ("we_don'", 't_have'),
#   ('it_may', 'be'),
#   ('i_have', 'been'),
#   ('in_the', 'world'),
#   ('a_set', 'of'),
#   ("there'_s", 'no'),
#   ('as_a', 'result_of'),
#   ("this_isn'", 't'),
#   ("they_don'", 't'),
#   ('in_this', 'country'),
#   ('i_am', 'not'),
#   ('that_can', 'be'),
#   ('seem_to', 'be'),
#   ("i_don'", 't_want'),
#   ('as_long', 'as'),
#   ('the_same', 'thing'),
#   ('the_difference', 'between'),
#   ("but_that'", 's'),
#   ('it_has', 'been'),
#   ('the_fact', 'that'),
#   ('thanks_in', 'advance_for'),
#   ('what_kind', 'of'),
#   ("we'_re", 'going_to'),
#   ('first', 'of_all'),
#   ('one_of', 'these'),
#   ('to_keep', 'and_bear'),
#   ('does_anyone', 'know_of'),
#   ('when_it', 'comes_to'),
#   ('x_window', 'system'),
#   ('office_of', 'the_press'),
#   ('professor_of', 'history'),
#   ('for_immediate', 'release'),
#   ('if_you', 'have_a'),
#   ('it_should', 'be'),
#   ('there', 'have_been'),
#   ('the_press', 'secretary'),
#   ('on', 'it'),
#   ('libxmu.a_is', 'undefined'),
#   ('not_to', 'mention'),
#   ('turks_and', 'kurds'),
#   ('that_i', 'am'),
#   ('and_so', 'on'),
#   ('women_and', 'children'),
#   ('anyone_out', 'there'),
#   ('but_i', 'think'),
#   ('the_second', 'amendment'),
#   ('it_does', 'not'),
#   ('going_to', 'be'),
#   ('e._coli', 'o157'),
#   ('is_it', 'true_that'),
#   ('and_of', 'course'),
#   ('for', 'that_matter'),
#   ('ivy_league', 'champs'),
#   ('as_a', 'result'),
#   ('there_are', 'many'),
#   ('in_any', 'way'),
#   ('all_the', 'time'),
#   ('out_of', 'the'),
#   ('a_list', 'of'),
#   ("i'_ve", 'got'),
#   ('soviet_armenian', 'government'),
#   ('some_kind', 'of'),
#   ('the_only', 'thing'),
#   ('is', 'this'),
#   ('in_terms', 'of'),
#   ('any_help', 'would_be'),
#   ('quite_a', 'few'),
#   ('a_bunch', 'of'),
#   ("i_haven'", 't_seen'),
#   ('this_is', 'not'),
#   ('the_problem', 'is_that'),
#   ('and_i', 'am'),
#   ('would_be', 'greatly_appreciated'),
#   ('is_there', 'any'),
#   ("i'_m", 'not_going'),
#   ('one_of', 'those'),
#   ("i'_ve", 'heard'),
#   ('hall_of', 'fame'),
#   ('as_i', 'said'),
#   ("that'_s", 'why'),
#   ("don'_t", 'want_to'),
#   ('south_georgia', 'island'),
#   ('i_have', 'seen'),
#   ('because_of', 'the'),
#   ("it'_s", 'a'),
#   ('does_anyone', 'have_any'),
#   ('for_a', 'long_time'),
#   ('via_anonymous', 'ftp_from'),
#   ('how_can', 'i'),
#   ('that_it', 'was'),
#   ('as_i', 'recall'),
#   ('for', 'you'),
#   ('in_the', 'same'),
#   ("that_doesn'", 't'),
#   ("you'_ve", 'got'),
#   ('as_well', 'as_the'),
#   ('bob_beauchaine', 'bobbe@vice.ico.tek.com'),
#   ('that_queens', 'could_stay'),
#   ('and_i', "don'_t"),
#   ('keep', 'in_mind'),
#   ("they_didn'", 't'),
#   ('all_of', 'the'),
#   ('i_get', 'an_x'),
#   ('floppy_disk', 'drives'),
#   ('and_sank', 'manhattan_out'),
#   ('for_more', 'information'),
#   ('a_few', 'years_ago'),
#   ('make_me', 'an_offer'),
#   ('that_i', 'have'),
#   ('needs_to', 'be'),
#   ('there_will', 'be'),
#   ('what_do', 'you_mean'),
#   ('one_of', 'them'),
#   ('manhattan_out', 'at_sea'),
#   ('let_me', 'know'),
#   ('via_anonymous', 'ftp'),
#   ('send_requests', 'to'),
#   ('that_they', 'are'),
#   ('is_it', 'possible_to'),
#   ('have_to', 'be'),
#   ('insisting_on', 'perfect_safety'),
#   ('what_is', 'the'),
#   ("can'_t", 'be'),
#   ('to_do', 'with'),
#   ('to_do', 'so'),
#   ('at_this', 'time'),
#   ('the_rest', 'of_the'),
#   ("why_can'", 't'),
#   ('what_do', 'you_think'),
#   ('for_some', 'reason'),
#   ('the_federal', 'government'),
#   ('looking_for', 'a'),
#   ('make_an', 'offer'),
#   ('that_there', 'is_no'),
#   ('for_the', 'most_part'),
#   ('the_fact', 'that_the'),
#   ('if_you', 'have_any'),
#   ('there_are', 'no'),
#   ("i_can'", 't_remember'),
#   ('but_i', "can'_t"),
#   ("what_i'", 'm'),
#   ('i_am', 'trying_to'),
#   ('there_was', 'a'),
#   ('will_not', 'be'),
#   ('or_something', 'like_that'),
#   ('no_matter', 'how'),
#   ('the_ottoman', 'empire'),
#   ('it_would', 'be_nice'),
#   ('this_is', 'not_a'),
#   ('freedom_of', 'speech'),
#   ('this_kind', 'of'),
#   ('does_anyone', 'know_if'),
#   ('it_is', 'a'),
#   ('in_the', 'future'),
#   ("i_wasn'", 't'),
#   ('on_the', 'road'),
#   ('do_you', 'think'),
#   ('as_far', 'as_the'),
#   ('is_there', 'a'),
#   ("there_isn'", 't'),
#   ('it_can', 'be'),
#   ('there_are', 'two'),
#   ('if_your', 'entry'),
#   ("please_don'", 't'),
#   ('in_the', 'us'),
#   ('they_said', 'that_queens'),
#   ('the_first', 'time'),
#   ('that_they', 'were'),
#   ('what', 'the'),
#   ('city_party', 'committee'),
#   ('world_war', 'ii'),
#   ('thing_to', 'do'),
#   ('how_do', 'you_know'),
#   ('is_one', 'of_the'),
#   ('for', 'it'),
#   ("i'_d", 'love_to'),
#   ("think_it'", 's'),
#   ('there_was', 'no'),
#   ('end_of', 'the'),
#   ('supposed_to', 'be'),
#   ("let'_s", 'go_quakers'),
#   ("let'_s", 'go_rangers'),
#   ('for_more', 'info'),
#   ("i'_ve", 'tried'),
#   ("i_don'", 't_remember'),
#   ('in_response', 'to'),
#   ("you_don'", 't_have'),
#   ('vesa_local', 'bus'),
#   ('it_must', 'be'),
#   ('more', 'or_less'),
#   ('on_the', 'subject'),
#   ('frequently_asked', 'questions'),
#   ("that_they'", 're'),
#   ('please_do', 'not'),
#   ("why_doesn'", 't'),
#   ("they_aren'", 't'),
#   ("we_can'", 't'),
#   ('all_of', 'them'),
#   ('a_while', 'ago'),
#   ("rod_brind'", 'amour'),
#   ('nasa_ames', 'dryden'),
#   ('please_tell', 'me'),
#   ('but_i', 'am'),
#   ("don'_t", 'think'),
#   ('if_there', 'is'),
#   ('for_the', 'sake_of'),
#   ("entry'_s", 'output_file'),
#   ("he_didn'", 't'),
#   ("i_wouldn'", 't'),
#   ('this_sort', 'of'),
#   ('denizens', 'of_doom'),
#   ('toronto_maple', 'leafs'),
#   ('or', 'at_least'),
#   ('please_send', 'me'),
#   ('in_the', 'case_of'),
#   ('in_my', 'mind'),
#   ('in_the', 'bible'),
#   ('you_might', 'want_to'),
#   ('thanx', 'in_advance'),
#   ('it_looks', 'like'),
#   ('i_am', 'not_sure'),
#   ('escrow_data', 'banks'),
#   ('at_the', 'moment'),
#   ('output_file', 'stream'),
#   ('available_via', 'anonymous_ftp'),
#   ('to', 'you'),
#   ('if_anyone', 'knows'),
#   ('can_anyone', 'tell_me'),
#   ("i_won'", 't'),
#   ('thanks_for', 'your_help'),
#   ('but_it', "doesn'_t"),
#   ('come_up', 'with'),
#   ('in_the', 'u.s.'),
#   ('in_the', 'middle_of'),
#   ('a_lot', 'of_people'),
#   ('and', 'at_bits'),
#   ('of_the', 'united_states'),
#   ('does_anyone', 'know'),
#   ("there'_s", 'a'),
#   ('are_available', 'via_anonymous'),
#   ('the_most', 'important'),
#   ('the_people', 'who'),
#   ('to_make', 'it'),
#   ('in_the', 'united_states'),
#   ('to_make', 'sure_that'),
#   ('in_our', 'apartment'),
#   ('on_this', 'subject'),
#   ('there_are', 'several'),
#   ('a_little', 'bit'),
#   ('that_there', 'are'),
#   ('is_based', 'on'),
#   ('international_obfuscated', 'c_code'),
#   ('all_kinds', 'of'),
#   ('genocide_of', '2.5_million'),
#   ('is_available', 'from'),
#   ('mileage_may', 'vary'),
#   ('as_a', 'matter_of'),
#   ("doesn'_t", 'work'),
#   ('most_of', 'the_time'),
#   ('i_do', 'not_believe'),
#   ('does_anyone', 'know_where'),
#   ('at_the', 'beginning_of'),
#   ('need_to', 'be'),
#   ("i_couldn'", 't'),
#   ('there_are', 'some'),
#   ('patrick_l.', 'mahan'),
#   ('up', 'the'),
#   ('needless_to', 'say'),
#   ('it_would', 'be_a'),
#   ('with_the', 'exception_of'),
#   ('that_is', 'not'),
#   ("won'_t", 'be'),
#   ('a_variety', 'of'),
#   ('in_this', 'group'),
#   ("you'_ll", 'have_to'),
#   ("i'_ll", 'be'),
#   ('the_original', 'poster'),
#   ('a_matter', 'of'),
#   ("it_won'", 't_be'),
#   ('read_this', 'group'),
#   ('wondering_if', 'anyone'),
#   ('in_the', 'last'),
#   ("i'_m", 'going_to'),
#   ('as_long', 'as_the'),
#   ('and', 'a'),
#   ("if_you'", 're_interested'),
#   ('of_the', 'world'),
#   ('in_front', 'of'),
#   ('or', 'is_it'),
#   ('there_is', 'no_way'),
#   ('the', 'use_of'),
#   ('so_you', 'can'),
#   ("because_it'", 's'),
#   ("what_you'", 're'),
#   ('how_do', 'you'),
#   ('to_be', 'a'),
#   ('according_to', 'the'),
#   ('between_the', 'two'),
#   ('that_has', 'been'),
#   ('y_or', 'n'),
#   ('is_no', 'longer'),
#   ('optional_rom', 'bios'),
#   ('due_to', 'the'),
#   ('i_have', 'the_following'),
#   ('of_their', 'own'),
#   ('please_email', 'me'),
#   ('could_have', 'been'),
#   ('thank_you', 'very_much'),
#   ('law_enforcement', 'agencies'),
#   ('i_would', 'appreciate'),
#   ('if', 'a'),
#   ('if_you', 'can'),
#   ('if_it', 'is'),
#   ('i_have', 'no_idea'),
#   ('i_have', 'heard'),
#   ('shots', 'on_goal-'),
#   ('have', 'the'),
#   ('which_can', 'be'),
#   ('to_do', 'this'),
#   ('t_know', 'what'),
#   ('signed_by', 'liefeld'),
#   ("we_don'", 't'),
#   ('if_you', "can'_t"),
#   ('appear_to', 'be'),
#   ('for_a', 'friend'),
#   ('any_of', 'the'),
#   ('that_he', 'was'),
#   ('it_might', 'be'),
#   ('is_there', 'any_way'),
#   ("what'_s", 'going_on'),
#   ('so_i', "don'_t"),
#   ('that_will', 'be'),
#   ('the_holy', 'spirit'),
#   ('as', 'to'),
#   ("you_don'", 't_know'),
#   ('version_of', 'the'),
#   ('i_do', 'not_know'),
#   ('that_you', 'are'),
#   ("user'_s", 'guide'),
#   ('here_are', 'some'),
#   ('there_may', 'be'),
#   ('in_the', 'name_of'),
#   ('some_of', 'these'),
#   ('appears_to', 'be'),
#   ('does_anyone', 'know_what'),
#   ('as_opposed', 'to'),
#   ('some_time', 'ago'),
#   ('the_window', 'manager'),
#   ('if_they', 'are'),
#   ('they_are', 'not'),
#   ('university_of', 'california'),
#   ('tgv_window', 'washer'),
#   ('a_good', 'idea'),
#   ('it', 'to'),
#   ('the_serial', 'number'),
#   ('in_the', 'context_of'),
#   ('it', 'all'),
#   ('and_the', 'other'),
#   ('does_anyone', 'out_there'),
#   ('name_of', 'the_output'),
#   ('everywhere', 'you_look'),
#   ('tampa_bay', 'lightning'),
#   ('when_they', 'were'),
#   ('why', 'are_you'),
#   ('on_the', 'basis_of'),
#   ('have', 'you_ever'),
#   ("and_i'", 'm_not'),
#   ('thanks', 'a_lot'),
#   ('is_one', 'byte'),
#   ('i_think', "it'_s"),
#   ('balls', 'to_live'),
#   ("i'_ve", 'had'),
#   ("i'_ve", 'got_a'),
#   ('to_get', 'rid_of'),
#   ('seem_to', 'recall'),
#   ('hard_disk', 'controller_card'),
#   ("he_wasn'", 't'),
#   ('all_sorts', 'of'),
#   ('anonymous_ftp', 'from'),
#   ('the_whole', 'thing'),
#   ('time_to', 'time'),
#   ('could', 'you'),
#   ('know_where', 'i_can'),
#   ('in_the', 'middle'),
#   ('what_you', 'want'),
#   ("haven'_t", 'seen'),
#   ('god_does', 'not_exist'),
#   ("the_qur'", 'an'),
#   ('is_not', 'a'),
#   ("if_they'", 're'),
#   ("but_it'", 's_not'),
#   ('if_there', 'is_a'),
#   ('as_it', 'is'),
#   ('has_nothing', 'to_do'),
#   ('that_could', 'be'),
#   ('many_of', 'the'),
#   ('have', 'you'),
#   ('in_many', 'cases'),
#   ('the_amount', 'of'),
#   ('you_can', 'use'),
#   ("i'_m", 'not_saying'),
#   ('should_have', 'been'),
#   ('printf("\\nplease_answer', 'y_or'),
#   ('for_those', 'who'),
#   ('post', 'a_summary'),
#   ('if_anyone', 'has'),
#   ('in_which', 'case'),
#   ('the_same', 'problem'),
#   ('the_rest', 'of_us'),
#   ('side_of', 'the'),
#   ('but_it', 'is'),
#   ('aristide_d.', 'caratzas'),
#   ('university_of', 'illinois'),
#   ('the_same', 'way'),
#   ("you_don'", 't_need'),
#   ('had_to', 'be'),
#   ('byte_ptr', 'cs:[bx'),
#   ('in_order', 'to_get'),
#   ('in_this', 'area'),
#   ('as_you', 'know'),
#   ('this_has', 'been'),
#   ('the_name', 'of_the'),
#   ('in_some', 'cases'),
#   ('baltimore', 'at_binghamton'),
#   ('take_a', 'look_at'),
#   ('vs_st', "john'_s"),
#   ('in_the', 'nhl'),
#   ('as_an', 'example'),
#   ("i_don'", 't_like'),
#   ('in_this', 'regard'),
#   ('of_the', 'bible'),
#   ('has_not', 'been'),
#   ('cambridge_university', 'press'),
#   ('a_very', 'good'),
#   ('the_best', 'way_to'),
#   ("st_john'", 's'),
#   ('what_i', 'am'),
#   ('i_find', 'it'),
#   ('in_the', 'real_world'),
#   ("driver'_s", 'license'),
#   ('look_at', 'the'),
#   ('as_much', 'as'),
#   ("that'_s", 'not'),
#   ('there_is', 'no_need'),
#   ('likely_to', 'be'),
#   ('any_of', 'these'),
#   ('t_have', 'any'),
#   ('quite_a', 'bit'),
#   ('what_is', 'going_on'),
#   ('that_i', 'can'),
#   ("you_haven'", 't'),
#   ('may_have', 'been'),
#   ('can_be', 'found_in'),
#   ('more_than', 'one'),
#   ('all_of', 'these'),
#   ('privacy_enhanced', 'mail'),
#   ("i'_m", 'trying_to'),
#   ("shouldn'_t", 'be'),
#   ("i_didn'", 't_say'),
#   ('does_not', 'mean'),
#   ("i_can'", 't_say'),
#   ('with_an', 'st506'),
#   ("i_don'", 't_care'),
#   ('i_did', 'not'),
#   ('i_am', 'interested_in'),
#   ("you'_re", 'not'),
#   ('to_come', 'up_with'),
#   ('the_new', 'york_times'),
#   ('thanks_for', 'any_help'),
#   ('in_the', 'process_of'),
#   ('and_i', 'think'),
#   ('members_of', 'the'),
#   ('to_say', 'that'),
#   ('on_your', 'own'),
#   ('in_the', 'league'),
#   ('among_other', 'things'),
#   ("you'_re", 'right'),
#   ('there_is', 'nothing'),
#   ('i_would', 'greatly_appreciate'),
#   ('of_the', 'church'),
#   ('it_seems', 'that'),
#   ('there_must', 'be'),
#   ("if_you'", 're_going'),
#   ('if_i', 'am'),
#   ('please_e-mail', 'me'),
#   ("i_didn'", 't_see'),
#   ('is_a', 'good'),
#   ('are_no', 'longer'),
#   ('can_you', 'tell_us'),
#   ("i_wouldn'", 't_be'),
#   ('one_of', 'the_most'),
#   ('my_question', 'is'),
#   ('to_have', 'a'),
#   ("i_don'", 't_understand'),
#   ('university_of', 'colorado'),
#   ('i_can', 'think_of'),
#   ('can_be', 'used_to'),
#   ("i_can'", 't_see'),
#   ('one_of', 'the_best'),
#   ('why_do', 'you'),
#   ('should_not', 'be'),
#   ('as_long', 'as_you'),
#   ('such_a', 'thing'),
#   ('i_think', 'that'),
#   ('the_question', 'is'),
#   ('if_you', 'do'),
#   ('is_that', 'the'),
#   ('is_a', 'very'),
#   ('comprehensive_cancer', 'center'),
#   ('there', 'would_be'),
#   ("he'_s", 'going_to'),
#   ('all_the', 'way'),
#   ('at_the', 'end'),
#   ('people_who', "don'_t"),
#   ("wouldn'_t", 'be'),
#   ('at', 'that'),
#   ('out', 'the'),
#   ('does_not', 'exist'),
#   ('diff_-t', '-c_-r1.18'),
#   ("doesn'_t", 'mean'),
#   ('because_they', 'are'),
#   ('let_me', 'know_if'),
#   ('seems_to', 'be_a'),
#   ('nasa_lewis', 'research_center'),
#   ('if_this', 'is_true'),
#   ('it_is', 'possible_to'),
#   ('i', 'seem_to'),
#   ('council_of', 'ministers'),
#   ('end_of', 'part'),
#   ('i_agree', 'with'),
#   ('if_it', 'was'),
#   ("and_i'", 'd_like'),
#   ('edited_by', 'samuel_shahmuradian'),
#   ('what_you', 'mean_by'),
#   ('on_the', 'same'),
#   ("hasn'_t", 'been'),
#   ("just_don'", 't'),
#   ('are_you', 'saying_that'),
#   ('2.5_million', 'muslim_people'),
#   ('m_not', 'sure'),
#   ('none_of', 'them'),
#   ('the_problem', 'is'),
#   ('includes_an', 'optional_rom'),
#   ('or', 'a'),
#   ('must_have', 'been'),
#   ("and_i'", 've'),
#   ('keep', 'and_bear'),
#   ('friend_of', 'mine'),
#   ('that_would', 'be'),
#   ('over_the', 'past'),
#   ('without', 'the'),
#   ("i_don'", 't_mean'),
#   ('at', 'any'),
#   ('where_i', 'can_find'),
#   ('with_the', 'same'),
#   ('as', 'such'),
#   ('sort_of', 'thing'),
#   ('is_going', 'to_be'),
#   ('of_the', 'law'),
#   ("and_i'", 'm_sure'),
#   ('million_muslim', 'people'),
#   ("that_doesn'", 't_mean'),
#   ('i_thought', 'it_was'),
#   ('when_i', 'was'),
#   ('are_you', 'going_to'),
#   ("let'_s", 'say'),
#   ("system'_s", 'rom_bios'),
#   ('one', 'or_more'),
#   ('as_i', 'understand'),
#   ('for_this', 'reason'),
#   ('an_x', 'server'),
#   ("that_it'", 's_not'),
#   ('such_a', 'thing_as'),
#   ('you_do', 'not'),
#   ('the_only', 'way'),
#   ('why_do', 'you_think'),
#   ('what_was', 'going_on'),
#   ('to_amend', 'title_18'),
#   ('if_they', 'were'),
#   ('where_i', 'can_get'),
#   ('the_bible', 'teaches'),
#   ('exactly', 'the_same'),
#   ('you_may', 'want_to'),
#   ("don'_t", 'want'),
#   ("don'_t", 'know_what'),
#   ('san_jose', 'sharks'),
#   ("isn'_t", 'it'),
#   ('any_kind', 'of'),
#   ('controller_card', 'with_an'),
#   ('the_other', 'day'),
#   ('if_it', 'were'),
#   ('if', 'one'),
#   ('rll_hard', 'disk_drives'),
#   ('with_respect', 'to'),
#   ('come', 'on'),
#   ('to_do', 'with_the'),
#   ('a_few', 'years'),
#   ('to', 'your'),
#   ("don'_t", 'forget'),
#   ('the_bottom', 'line'),
#   ("doesn'_t", 'seem_to'),
#   ("but_i'", 've'),
#   ('committed_to', 'working_with'),
#   ('general_unified', 'theory'),
#   ("i'_m", 'afraid'),
#   ('does_this', 'mean_that'),
#   ('no_matter', 'what'),
#   ('which_has', 'been'),
#   ("don'_t", 'get'),
#   ('the_output', 'file'),
#   ('to_do', 'it'),
#   ('___', 'the'),
#   ('armegedon_2001', 'tie'),
#   ('2_2', '2_3'),
#   ('2_3', '2_2'),
#   ('like_to', 'know'),
#   ('available_by', 'anonymous_ftp'),
#   ("they_won'", 't'),
#   ('on_this', 'topic'),
#   ('you_can', 'get'),
#   ('does_not', 'mean_that'),
#   ('has_anyone', 'else'),
#   ('you_can', 'also'),
#   ('in_the', 'meantime'),
#   ('does_anyone', 'have'),
#   ('all', 'this'),
#   ('turn_out', 'to_be'),
#   ('about_a', 'year_ago'),
#   ('of_people', 'who'),
#   ('the_idea', 'of'),
#   ('as_good', 'as'),
#   ('at', 'some'),
#   ('please_mail', 'me'),
#   ('as_i', 'can_tell'),
#   ('on_the', 'ice'),
#   ('published_by', 'aristide_d.'),
#   ('what', 'to_do'),
#   ('do_i', 'have_to'),
#   ('8_mb', 'ram'),
#   ('if_i', 'remember'),
#   ('based_on', 'the'),
#   ('many_of', 'them'),
#   ('correct', 'me_if'),
#   ('if_you', 'need'),
#   ('seems_to', 'me_that'),
#   ('from', 'time_to'),
#   ('because_it', 'is'),
#   ('does_not', 'include'),
#   ('in_the', 'right_direction'),
#   ('but_it', 'was'),
#   ('dale', 'j._stephenson'),
#   ('of_the', 'same'),
#   ('what_was', 'happening'),
#   ('no_more', 'than'),
#   ('to_deal', 'with'),
#   ('on_the', 'moon'),
#   ('couple_of', 'weeks'),
#   ('unit_key', 'u'),
#   ('well_regulated', 'militia'),
#   ('use_the', 'same'),
#   ('does', 'that'),
#   ('for_more', 'details'),
#   ('in_the', 'usa'),
#   ('has', 'to_be'),
#   ('the_most', 'common'),
#   ('men_are', 'like_that'),
#   ('under_the', 'bed'),
#   ('and_so', 'forth'),
#   ('new_york', 'rangers'),
#   ('jet_propulsion', 'laboratory'),
#   ("don'_t", 'know_if'),
#   ("the_president'", 's'),
#   ("i'_d", 'be'),
#   ('on_top', 'of'),
#   ('dave_feustel', 'n9myi'),
#   ('to_get', 'the'),
#   ("i'_d", 'say'),
#   ('why_is', 'it'),
#   ('a_pretty', 'good'),
#   ('for', 'his'),
#   ('for_the', 'rest_of'),
#   ('i', 'live_in'),
#   ('going_to', 'continue_to'),
#   ('in', 'all'),
#   ('wall_street', 'journal'),
#   ('i_want', 'to_know'),
#   ('made', 'it'),
#   ('of_the', 'turkish'),
#   ('as_long', 'as_it'),
#   ('i_do', 'not_have'),
#   ('how', 'could'),
#   ('but_it', 'is_not'),
#   ('united_states', 'of_america'),
#   ('-----begin_pgp', 'signature-----'),
#   ('-----begin_pgp', 'signed_message-----'),
#   ('hp_idacom', 'telecom'),
#   ('the_right', 'to_keep'),
#   ('about_the', 'same'),
#   ('not_to', 'be'),
#   ('in_this', 'thread'),
#   ('i_just', "don'_t"),
#   ('from', 'what_i'),
#   ('are', 'they'),
#   ('i_want', 'to'),
#   ('a_bad', 'idea'),
#   ('no_such', 'thing_as'),
#   ("if_you'", 'd_like'),
#   ('over_the', 'next'),
#   ('a_little', 'more'),
#   ('this_will', 'be'),
#   ('thank_you', 'in_advance'),
#   ('on_the', 'other_side'),
#   ('there_is', 'also'),
#   ('but_i', "didn'_t"),
#   ('it_was', 'a'),
#   ('is_going', 'to'),
#   ('did', 'it'),
#   ('national', 'center_for'),
#   ('it_could', 'be'),
#   ('i', 'bet'),
#   ('this_is', 'why'),
#   ('i_just', 'bought_a'),
#   ('available_via', 'ftp'),
#   ('in_the', 'morning'),
#   ('to_begin', 'with'),
#   ('a_wide', 'range_of'),
#   ('please_reply', 'via_e-mail'),
#   ('the_will', 'of_god'),
#   ('in_his', 'own'),
#   ("if_you'", 're_not'),
#   ('for', 'use'),
#   ('as_a', 'whole'),
#   ('two_weeks', 'ago'),
#   ('all', 'that'),
#   ('if', 'anything'),
#   ('genocide_of', '2.5'),
#   ('trying_to', 'get'),
#   ('does_anyone', 'have_a'),
#   ('so_i', 'can'),
#   ('bear', 'with_me'),
#   ('if_there', 'is_no'),
#   ('up_to', '16_heads'),
#   ('library_of', 'congress'),
#   ("larson'_s", 'theory'),
#   ('seem_to', 'have'),
#   ('i_am', 'using'),
#   ('for_the', 'purpose_of'),
#   ('that_there', 'are_no'),
#   ('a_series', 'of'),
#   ('but_i', "haven'_t"),
#   ('to_make', 'a'),
#   ('wait', 'a_minute'),
#   ("that'_s", 'what'),
#   ("i'_m", 'using'),
#   ('could_not', 'be'),
#   ('thought_it', 'was'),
#   ('in_their', 'own'),
#   ('on_the', 'back'),
#   ('those_of', 'us'),
#   ('the_new', 'england_journal'),
#   ('should_be', 'able_to'),
#   ('the_anti-defamation', 'league'),
#   ('when_he', 'was'),
#   ('to', 'them'),
#   ('wondering_if', 'anyone_out'),
#   ('something_like', 'this'),
#   ('my', 'first'),
#   ('the_president', 'has'),
#   ('side_of', 'the_road'),
#   ('ansi_c', 'compilers'),
#   ("but_i'", 'll'),
#   ('i', 'called'),
#   ('on_your', "system'_s"),
#   ('on_the', 'screen'),
#   ('is_better', 'than'),
#   ('if', "i'_m"),
#   ('at_the', 'top_of'),
#   ('ati', 'graphics_ultra'),
#   ('this', 'file'),
#   ('i_was', 'wondering'),
#   ('one', 'or_two'),
#   ('it_is', 'also'),
#   ('of_the', 'the'),
#   ('in_my', 'case'),
#   ('i_can', 'get'),
#   ('love_to', 'hear'),
#   ('there_will', 'be_a'),
#   ('know_of', 'any'),
#   ('for_the', 'first_time'),
#   ('law_enforcement', 'agency'),
#   ('institute_of', 'technology'),
#   ('gun_control', 'laws'),
#   ('is_supposed', 'to_be'),
#   ('called', 'the'),
#   ('in_the', 'the'),
#   ('do_not', 'have'),
#   ('or', 'may_not'),
#   ('5_apr', '93'),
#   ('los_angeles', 'kings'),
#   ('can_be', 'used'),
#   ('a_large', 'number_of'),
#   ('on_its', 'own'),
#   ('the_new', 'testament'),
#   ('to', 'death'),
#   ('shall_not', 'be'),
#   ("i'_m", 'sorry'),
#   ('i_am', 'not_a'),
#   ('parts_of', 'the'),
#   ('the_existence', 'of'),
#   ('with', 'you'),
#   ('something', 'to_do'),
#   ('are_interested', 'in'),
#   ('that', 'time'),
#   ('a_wide', 'variety_of'),
#   ("someone_else'", 's'),
#   ('it_works', 'fine'),
#   ("i'_m", 'still'),
#   ('mb_hard', 'drive'),
#   ('tells', 'you'),
#   ('in', 'most_cases'),
#   ('there_is', 'no_such'),
#   ('david_b.', 'lewis'),
#   ('back_to', 'the'),
#   ('of_any', 'kind'),
#   ('because_they', 'were'),
#   ('one_of', 'my'),
#   ('for_some', 'time'),
#   ('drive_tables', 'on_your'),
#   ('in_an', 'effort_to'),
#   ('in_the', 'early'),
#   ('tom_mcwilliams', '517'),
#   ('feel_free', 'to'),
#   ("but_that'", 's_not'),
#   ('most_of', 'them'),
#   ('like_to', 'get'),
#   ('rest_of', 'the'),
#   ('in_the', 'near_future'),
#   ('just', 'in_case'),
#   ('but', 'now'),
#   ('a_lot', 'more'),
#   ('that_i', "don'_t"),
#   ('there_were', 'no'),
#   ('as_i', 'am'),
#   ('on_export', 'in'),
#   ('for_their', 'own'),
#   ('one_way', 'or'),
#   ('thanks', 'very_much'),
#   ("don'_t", 'bother'),
#   ('for', 'dos'),
#   ('i_would', 'be'),
#   ("it'_s", 'been'),
#   ('if_there', 'are'),
#   ('all_aspects', 'of'),
#   ('this', 'week'),
#   ('to_use', 'the'),
#   ('you', 'just'),
#   ('a_group', 'of'),
#   ('thanks_for', 'any_info'),
#   ('truelove_served', 'to_me'),
#   ('__the', 'sumgait_tragedy'),
#   ('feature_f301r', 'includes_an'),
#   ('boards', 'can_run'),
#   ('what_are', 'some'),
#   ('you_will', 'be'),
#   ('give_me', 'some'),
#   ('i_have', 'no'),
#   ("i'_m", 'wrong'),
#   ('c_code', 'contest'),
#   ("if_you'", 've_got'),
#   ('i_have', 'heard_that'),
#   ('for', 'years'),
#   ('is', 'about'),
#   ('the_turkish', 'genocide'),
#   ...]]

# %% [markdown]
# By default, it will not contract any token that is a non-word (under the regex r"\W+") but this can be easily changed as we will see later on.

# %% [markdown]
# The tokens are contracted on first-come-first-serve basis, one round at a time, ultimately producing the new sequence of (multi-)tokens.

# %%
new_tokens[0:3]
# Out:
# (('i_was_wondering_if',
#   'anyone_out_there',
#   'could',
#   'enlighten',
#   'me',
#   'on_this',
#   'car',
#   'i_saw',
#   '\n',
#   'the_other_day',
#   '.',
#   'it_was_a',
#   '2-door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to_be',
#   'from_the',
#   'late',
#   '60s/',
#   '\n',
#   'early',
#   '70s',
#   '.',
#   'it_was',
#   'called',
#   'a',
#   'bricklin',
#   '.',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small',
#   '.',
#   'in_addition',
#   ',',
#   '\n',
#   'the_front',
#   'bumper',
#   'was',
#   'separate',
#   'from_the',
#   'rest_of',
#   'the_body',
#   '.',
#   'this_is',
#   '\n',
#   'all',
#   'i_know',
#   '.',
#   'if_anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name',
#   ',',
#   'engine',
#   'specs',
#   ',',
#   'years',
#   '\n',
#   'of',
#   'production',
#   ',',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   ',',
#   'history',
#   ',',
#   'or_whatever',
#   'info',
#   'you',
#   '\n',
#   'have',
#   'on_this',
#   'funky',
#   'looking',
#   'car',
#   ',',
#   'please_e-mail',
#   '.'),
#  ('a_fair',
#   'number_of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have',
#   '\n',
#   'shared',
#   'their',
#   'experiences',
#   'for_this',
#   'poll',
#   '.',
#   'please_send',
#   'a_brief',
#   'message',
#   'detailing',
#   '\n',
#   'your',
#   'experiences',
#   'with_the',
#   'procedure',
#   '.',
#   'top',
#   'speed',
#   'attained',
#   ',',
#   'cpu',
#   'rated',
#   'speed',
#   ',',
#   '\n',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   ',',
#   'heat',
#   'sinks',
#   ',',
#   'hour',
#   'of',
#   'usage',
#   'per_day',
#   ',',
#   'floppy_disk',
#   '\n',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   '.',
#   '\n\n',
#   'i_will_be',
#   'summarizing',
#   'in_the_next',
#   'two_days',
#   ',',
#   'so',
#   'please',
#   'add',
#   'to_the',
#   'network',
#   '\n',
#   'knowledge',
#   'base',
#   'if_you',
#   'have_done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   "haven'_t",
#   'answered',
#   'this',
#   '\n',
#   'poll',
#   '.',
#   'thanks',
#   '.'),
#  ('well',
#   'folks',
#   ',',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave_up',
#   'the',
#   'ghost',
#   'this_weekend',
#   'after',
#   '\n',
#   'starting',
#   'life',
#   'as_a',
#   '512k',
#   'way',
#   'back_in',
#   '1985',
#   '.',
#   ' ',
#   'sooo',
#   ',',
#   "i'_m",
#   'in_the',
#   'market',
#   'for_a',
#   '\n',
#   'new',
#   'machine',
#   'a_bit',
#   'sooner',
#   'than',
#   'i',
#   'intended_to',
#   'be',
#   '...',
#   '\n\n',
#   "i'_m_looking",
#   'into',
#   'picking_up',
#   'a',
#   'powerbook',
#   '160',
#   'or_maybe',
#   '180',
#   'and',
#   'have_a',
#   'bunch',
#   '\n',
#   'of',
#   'questions',
#   'that',
#   '(',
#   'hopefully',
#   ')',
#   'somebody',
#   'can',
#   'answer',
#   ':',
#   '\n\n',
#   '*',
#   'does_anybody',
#   'know',
#   'any',
#   'dirt',
#   'on',
#   'when_the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   '\n',
#   'introductions',
#   'are',
#   'expected',
#   '?',
#   ' ',
#   "i'_d",
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed_to',
#   'make_an',
#   '\n',
#   'appearence',
#   '"',
#   'this_summer',
#   '"',
#   'but',
#   "haven'_t",
#   'heard',
#   'anymore',
#   'on_it',
#   '-',
#   'and',
#   'since_i',
#   '\n',
#   "don'_t",
#   'have_access',
#   'to',
#   'macleak',
#   ',',
#   'i_was_wondering_if',
#   'anybody',
#   'out_there',
#   'had',
#   '\n',
#   'more_info',
#   '...',
#   '\n\n',
#   '*',
#   'has_anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to_the',
#   'powerbook',
#   'line',
#   'like_the',
#   '\n',
#   'ones',
#   'the',
#   "duo'",
#   's_just',
#   'went_through',
#   'recently',
#   '?',
#   '\n\n',
#   '*',
#   "what'_s",
#   'the',
#   'impression',
#   'of_the',
#   'display',
#   'on_the',
#   '180',
#   '?',
#   ' ',
#   'i_could',
#   'probably',
#   'swing',
#   '\n',
#   'a',
#   '180',
#   'if_i',
#   'got',
#   'the',
#   '80mb',
#   'disk',
#   'rather_than',
#   'the',
#   '120',
#   ',',
#   "but_i_don'_t",
#   'really',
#   'have',
#   '\n',
#   'a',
#   'feel',
#   'for',
#   'how_much',
#   '"',
#   'better',
#   '"',
#   'the',
#   'display',
#   'is',
#   '(',
#   'yea',
#   ',',
#   'it_looks',
#   'great',
#   'in_the',
#   '\n',
#   'store',
#   ',',
#   'but',
#   'is_that',
#   'all',
#   '"',
#   'wow',
#   '"',
#   'or_is_it',
#   'really',
#   'that',
#   'good',
#   '?',
#   ')',
#   '.',
#   ' ',
#   'could',
#   'i',
#   'solicit',
#   '\n',
#   'some',
#   'opinions',
#   'of_people_who',
#   'use_the',
#   '160',
#   'and',
#   '180',
#   'day',
#   '-',
#   'to',
#   '-',
#   'day',
#   'on',
#   'if',
#   'its',
#   'worth',
#   '\n',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to_get_the',
#   'active',
#   'display',
#   '?',
#   ' ',
#   '(',
#   'i_realize',
#   '\n',
#   'this_is',
#   'a_real',
#   'subjective',
#   'question',
#   ',',
#   "but_i'_ve",
#   'only',
#   'played',
#   'around',
#   'with_the',
#   '\n',
#   'machines',
#   'in_a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   '\n',
#   'who',
#   'actually',
#   'uses',
#   'the_machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   ')',
#   '.',
#   '\n\n',
#   '*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   '?',
#   ' ',
#   ';)',
#   '\n\n',
#   'thanks',
#   'a_bunch',
#   'in_advance',
#   'for_any',
#   'info',
#   '-',
#   'if_you',
#   'could',
#   'email',
#   ',',
#   "i'_ll_post",
#   'a',
#   '\n',
#   'summary',
#   '(',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at_a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around_the',
#   '\n',
#   'corner',
#   '...',
#   ':(',
#   ')',
#   '\n',
#   '--',
#   '\n',
#   'tom',
#   'willis',
#   ' ',
#   '\\',
#   ' ',
#   'twillis@ecn.purdue.edu',
#   '   ',
#   '\\',
#   '   ',
#   'purdue',
#   'electrical_engineering'))

# %% [markdown]
# Notice that this has a tendency to combine stopwords into stop phrases as stop words tend to occur next to eachother much more often then one would expect by chance.  However, it also captures other bigrams you might expect like 'electrical_engineering', which helps distinguish this token from 'electrical' and 'engineering' when they occur seperatately.

# %% [markdown]
# Perhaps we want to ignore stop words for example.  In this case we can just add them to the ignored tokes.

# %%
mte = textmap.transformers.MultiTokenExpressionTransformer(ignored_tokens=stopwords.words('english'))
new_tokens = mte.fit_transform(tokens)

# %%
new_tokens[0:3]
# Out:
# (('i',
#   'was',
#   'wondering',
#   'if',
#   'anyone',
#   'out',
#   'there',
#   'could',
#   'enlighten',
#   'me',
#   'on',
#   'this',
#   'car',
#   'i',
#   'saw',
#   '\n',
#   'the',
#   'other',
#   'day',
#   '.',
#   'it',
#   'was',
#   'a',
#   '2-door',
#   'sports',
#   'car',
#   ',',
#   'looked',
#   'to',
#   'be',
#   'from',
#   'the',
#   'late',
#   '60s/',
#   '\n',
#   'early',
#   '70s',
#   '.',
#   'it',
#   'was',
#   'called',
#   'a',
#   'bricklin',
#   '.',
#   'the',
#   'doors',
#   'were',
#   'really',
#   'small',
#   '.',
#   'in',
#   'addition',
#   ',',
#   '\n',
#   'the',
#   'front',
#   'bumper',
#   'was',
#   'separate',
#   'from',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'body',
#   '.',
#   'this',
#   'is',
#   '\n',
#   'all',
#   'i',
#   'know',
#   '.',
#   'if',
#   'anyone',
#   'can',
#   'tellme',
#   'a',
#   'model',
#   'name',
#   ',',
#   'engine',
#   'specs',
#   ',',
#   'years',
#   '\n',
#   'of',
#   'production',
#   ',',
#   'where',
#   'this',
#   'car',
#   'is',
#   'made',
#   ',',
#   'history',
#   ',',
#   'or',
#   'whatever',
#   'info',
#   'you',
#   '\n',
#   'have',
#   'on',
#   'this',
#   'funky',
#   'looking',
#   'car',
#   ',',
#   'please_e-mail',
#   '.'),
#  ('a',
#   'fair',
#   'number',
#   'of',
#   'brave',
#   'souls',
#   'who',
#   'upgraded',
#   'their',
#   'si',
#   'clock',
#   'oscillator',
#   'have',
#   '\n',
#   'shared',
#   'their',
#   'experiences',
#   'for',
#   'this',
#   'poll',
#   '.',
#   'please_send',
#   'a',
#   'brief',
#   'message',
#   'detailing',
#   '\n',
#   'your',
#   'experiences',
#   'with',
#   'the',
#   'procedure',
#   '.',
#   'top',
#   'speed',
#   'attained',
#   ',',
#   'cpu',
#   'rated',
#   'speed',
#   ',',
#   '\n',
#   'add',
#   'on',
#   'cards',
#   'and',
#   'adapters',
#   ',',
#   'heat',
#   'sinks',
#   ',',
#   'hour',
#   'of',
#   'usage',
#   'per_day',
#   ',',
#   'floppy_disk',
#   '\n',
#   'functionality',
#   'with',
#   '800',
#   'and',
#   '1.4',
#   'm',
#   'floppies',
#   'are',
#   'especially',
#   'requested',
#   '.',
#   '\n\n',
#   'i',
#   'will',
#   'be',
#   'summarizing',
#   'in',
#   'the',
#   'next',
#   'two_days',
#   ',',
#   'so',
#   'please',
#   'add',
#   'to',
#   'the',
#   'network',
#   '\n',
#   'knowledge',
#   'base',
#   'if',
#   'you',
#   'have',
#   'done',
#   'the',
#   'clock',
#   'upgrade',
#   'and',
#   "haven'",
#   't',
#   'answered',
#   'this',
#   '\n',
#   'poll',
#   '.',
#   'thanks',
#   '.'),
#  ('well',
#   'folks',
#   ',',
#   'my',
#   'mac',
#   'plus',
#   'finally',
#   'gave',
#   'up',
#   'the',
#   'ghost',
#   'this',
#   'weekend',
#   'after',
#   '\n',
#   'starting',
#   'life',
#   'as',
#   'a',
#   '512k',
#   'way',
#   'back',
#   'in',
#   '1985',
#   '.',
#   ' ',
#   'sooo',
#   ',',
#   "i'",
#   'm',
#   'in',
#   'the',
#   'market',
#   'for',
#   'a',
#   '\n',
#   'new',
#   'machine',
#   'a',
#   'bit',
#   'sooner',
#   'than',
#   'i',
#   'intended',
#   'to',
#   'be',
#   '...',
#   '\n\n',
#   "i'",
#   'm',
#   'looking',
#   'into',
#   'picking',
#   'up',
#   'a',
#   'powerbook',
#   '160',
#   'or',
#   'maybe',
#   '180',
#   'and',
#   'have',
#   'a',
#   'bunch',
#   '\n',
#   'of',
#   'questions',
#   'that',
#   '(',
#   'hopefully',
#   ')',
#   'somebody',
#   'can',
#   'answer',
#   ':',
#   '\n\n',
#   '*',
#   'does',
#   'anybody_know',
#   'any',
#   'dirt',
#   'on',
#   'when',
#   'the',
#   'next',
#   'round',
#   'of',
#   'powerbook',
#   '\n',
#   'introductions',
#   'are',
#   'expected',
#   '?',
#   ' ',
#   "i'",
#   'd',
#   'heard',
#   'the',
#   '185c',
#   'was',
#   'supposed',
#   'to',
#   'make',
#   'an',
#   '\n',
#   'appearence',
#   '"',
#   'this',
#   'summer',
#   '"',
#   'but',
#   "haven'",
#   't',
#   'heard',
#   'anymore',
#   'on',
#   'it',
#   '-',
#   'and',
#   'since',
#   'i',
#   '\n',
#   "don'",
#   't',
#   'have',
#   'access',
#   'to',
#   'macleak',
#   ',',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'anybody',
#   'out',
#   'there',
#   'had',
#   '\n',
#   'more',
#   'info',
#   '...',
#   '\n\n',
#   '*',
#   'has',
#   'anybody',
#   'heard',
#   'rumors',
#   'about',
#   'price',
#   'drops',
#   'to',
#   'the',
#   'powerbook',
#   'line',
#   'like',
#   'the',
#   '\n',
#   'ones',
#   'the',
#   "duo'",
#   's',
#   'just',
#   'went',
#   'through',
#   'recently',
#   '?',
#   '\n\n',
#   '*',
#   "what'",
#   's',
#   'the',
#   'impression',
#   'of',
#   'the',
#   'display',
#   'on',
#   'the',
#   '180',
#   '?',
#   ' ',
#   'i',
#   'could',
#   'probably',
#   'swing',
#   '\n',
#   'a',
#   '180',
#   'if',
#   'i',
#   'got',
#   'the',
#   '80mb',
#   'disk',
#   'rather',
#   'than',
#   'the',
#   '120',
#   ',',
#   'but',
#   'i',
#   "don'",
#   't',
#   'really',
#   'have',
#   '\n',
#   'a',
#   'feel',
#   'for',
#   'how',
#   'much',
#   '"',
#   'better',
#   '"',
#   'the',
#   'display',
#   'is',
#   '(',
#   'yea',
#   ',',
#   'it',
#   'looks',
#   'great',
#   'in',
#   'the',
#   '\n',
#   'store',
#   ',',
#   'but',
#   'is',
#   'that',
#   'all',
#   '"',
#   'wow',
#   '"',
#   'or',
#   'is',
#   'it',
#   'really',
#   'that',
#   'good',
#   '?',
#   ')',
#   '.',
#   ' ',
#   'could',
#   'i',
#   'solicit',
#   '\n',
#   'some',
#   'opinions',
#   'of',
#   'people',
#   'who',
#   'use',
#   'the',
#   '160',
#   'and',
#   '180',
#   'day',
#   '-',
#   'to',
#   '-',
#   'day',
#   'on',
#   'if',
#   'its',
#   'worth',
#   '\n',
#   'taking',
#   'the',
#   'disk',
#   'size',
#   'and',
#   'money',
#   'hit',
#   'to',
#   'get',
#   'the',
#   'active',
#   'display',
#   '?',
#   ' ',
#   '(',
#   'i',
#   'realize',
#   '\n',
#   'this',
#   'is',
#   'a',
#   'real',
#   'subjective',
#   'question',
#   ',',
#   'but',
#   "i'",
#   've',
#   'only',
#   'played',
#   'around',
#   'with',
#   'the',
#   '\n',
#   'machines',
#   'in',
#   'a',
#   'computer',
#   'store',
#   'breifly',
#   'and',
#   'figured',
#   'the',
#   'opinions',
#   'of',
#   'somebody',
#   '\n',
#   'who',
#   'actually',
#   'uses',
#   'the',
#   'machine',
#   'daily',
#   'might',
#   'prove',
#   'helpful',
#   ')',
#   '.',
#   '\n\n',
#   '*',
#   'how',
#   'well',
#   'does',
#   'hellcats',
#   'perform',
#   '?',
#   ' ',
#   ';)',
#   '\n\n',
#   'thanks',
#   'a',
#   'bunch',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'info',
#   '-',
#   'if',
#   'you',
#   'could',
#   'email',
#   ',',
#   "i'",
#   'll',
#   'post',
#   'a',
#   '\n',
#   'summary',
#   '(',
#   'news',
#   'reading',
#   'time',
#   'is',
#   'at',
#   'a',
#   'premium',
#   'with',
#   'finals',
#   'just',
#   'around',
#   'the',
#   '\n',
#   'corner',
#   '...',
#   ':(',
#   ')',
#   '\n',
#   '--',
#   '\n',
#   'tom',
#   'willis',
#   ' ',
#   '\\',
#   ' ',
#   'twillis@ecn.purdue.edu',
#   '   ',
#   '\\',
#   '   ',
#   'purdue',
#   'electrical_engineering'))

# %% [markdown]
# You can also filter the tokens to contract in various ways, including minimum and maximum frequencies (or number of occurrences) or regex expression, or only contract ngrams if the pair occur sufficiently often.  You can also set the maximal number of iterations to be larger or small to control the maximal lenght of a contracted n-gram.

# %%
mte = textmap.transformers.MultiTokenExpressionTransformer(max_token_frequency = 1e-4, 
                                                           min_token_occurrences = 50, 
                                                           min_ngram_occurrences = 30,
                                                           excluded_token_regex="\W",
                                                           max_iterations=1
                                                          )
mte.fit(tokens)
mte.mtes_
# Out:
# [[('los', 'angeles'),
#   ('serdar', 'argic'),
#   ('gordon', 'banks'),
#   ('st.', 'louis'),
#   ('greatly', 'appreciated'),
#   ('newsletter', '                                             '),
#   ('et', 'al'),
#   ('apr', '93'),
#   ('hicnet', 'medical'),
#   ('                                             ', 'page'),
#   ('holy', 'spirit'),
#   ('tampa', 'bay'),
#   ('bear', 'arms'),
#   ('rom', 'bios'),
#   ('stanley', 'cup'),
#   ('medical', 'newsletter'),
#   ('maple', 'leafs'),
#   ('cross', 'linked'),
#   ('------', '------'),
#   ('tear', 'gas'),
#   ('allocation', 'unit'),
#   ('excellent', 'condition'),
#   ('soviet', 'union'),
#   ('virtual', 'reality'),
#   ('cubs', 'suck'),
#   ('remote', 'sensing'),
#   ('ottoman', 'empire'),
#   ('red', 'sox'),
#   ('red', 'wings'),
#   ("o'", 'clock'),
#   ('mailing', 'lists'),
#   ('st', "john'"),
#   ('south', 'georgia'),
#   ('radar', 'detector'),
#   ('serial', 'port'),
#   ('soviet', 'armenia'),
#   ('middle', 'east'),
#   ('summer', 'jobs'),
#   ('western', 'digital')]]

# %% [markdown]
# (Yes some one of the tokens is lots of white space in this example... meh... it's just an example)
#
# You can also change the minimal score to merge an n-gram and/or the score function itself to anything that behaves like those found in nltk.metrics.BigramAssocMeasures

# %%
from nltk.metrics import BigramAssocMeasures

# %%
# %%time
mte = textmap.transformers.MultiTokenExpressionTransformer(score_function=BigramAssocMeasures.chi_sq,
                                                           min_score = 1e5,
                                                           max_token_frequency = 1e-4, 
                                                           min_token_occurrences = 50, 
                                                           min_ngram_occurrences = 30,
                                                           excluded_token_regex="\W",
                                                           max_iterations=1
                                                          )
mte.fit(tokens)
mte.mtes_
# Out:
# CPU times: user 11.5 s, sys: 64.5 ms, total: 11.6 s
# Wall time: 11.6 s
# [[('serdar', 'argic'),
#   ('los', 'angeles'),
#   ('newsletter', '                                             '),
#   ('gordon', 'banks'),
#   ('tampa', 'bay'),
#   ('stanley', 'cup'),
#   ('maple', 'leafs'),
#   ('                                             ', 'page'),
#   ('st.', 'louis'),
#   ('cubs', 'suck'),
#   ('hicnet', 'medical'),
#   ('st', "john'"),
#   ('ottoman', 'empire'),
#   ('cross', 'linked'),
#   ('remote', 'sensing'),
#   ('------', '------'),
#   ('et', 'al'),
#   ('bear', 'arms'),
#   ('tear', 'gas'),
#   ('radar', 'detector'),
#   ('holy', 'spirit'),
#   ('greatly', 'appreciated'),
#   ('allocation', 'unit'),
#   ('medical', 'newsletter'),
#   ('apr', '93'),
#   ('rom', 'bios'),
#   ('soviet', 'union'),
#   ('red', 'sox'),
#   ('south', 'georgia'),
#   ('virtual', 'reality'),
#   ('mailing', 'lists'),
#   ("o'", 'clock'),
#   ('red', 'wings')]]
